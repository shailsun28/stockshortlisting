# %%
import pandas as pd
from datetime import datetime, timedelta
import sqlite3
import os 
BASE_DIR_db = "/home/shail/db"

# %%
stock = 'TCS'

# %%
import sqlite3
import pandas as pd
import os

BASE_DIR_db = "/home/shail/db"
db_path = os.path.join(BASE_DIR_db, "fnodailydata.db")

# Connect to SQLite
conn = sqlite3.connect(db_path)

# Get list of all tables
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
table_names = tables['name'].tolist()

# Dictionary to hold DataFrames
dfs = {}

for name in table_names:
    try:
        query = f'SELECT * FROM "{name}" ORDER BY Date DESC'
        df = pd.read_sql_query(query, conn)
        dfs[name] = df
        print(f"Loaded table: {name}, rows: {len(df)}")
    except Exception as e:
        print(f"Skipped table {name} due to error: {e}")

conn.close()
fii = dfs['fii']
fno = dfs['fnototal']
fuidx = dfs['fuidx']
fustk = dfs['fustk']
oi = dfs['participant_oi']
vol = dfs['participant_vol']
# Example: access a specific table DataFrame
# print(dfs['fii'].head())
# Out:
# Loaded table: participant_oi, rows: 1015
# Loaded table: participant_vol, rows: 1015
# Loaded table: fustk, rows: 41956
# Loaded table: fii, rows: 2954
# Loaded table: fuidx_pct_vol, rows: 995
# Loaded table: opidx_pct_oi, rows: 995
# Loaded table: fuidx, rows: 1182
# Loaded table: fnototal, rows: 985

# %%
fno_df.head()
# Out:
#         Stock  dly_RTO  prchg%  qty_rto     High  cur_dly  cur_trd_qty  \
# 0         ABB     6.16    8.55    10.55  5547.50   662694      2314066
# 15    SBICARD     4.17   -1.40     4.72   785.00  2175729      4774219
# 13  PPLPHARMA     3.36    0.12     5.88   163.24  3941385     16425045
# 8       LODHA     3.34    2.43     2.74   959.00  3234588      5778176
# 14       RVNL     3.17   -0.04     3.05   352.80  5964575     23000058
#
#        Tval    Tvol      LTP      Low     VWAP   prchg  pRange    Val_CR  \
# 0   1304.45   23.89  5474.50  4983.50  5461.28  431.00  564.00  1361.109
# 15   380.01   49.37   771.45   751.75   769.65  -10.95   33.25   424.331
# 13   265.06  167.74   154.14   148.31   158.02    0.18   14.93   279.691
# 8    554.74   58.89   951.70   904.10   942.02   22.60   54.90   577.273
# 14   828.92  244.41   342.35   331.20   339.15   -0.15   21.60   917.914
#
#          Vol  DlyAvg_10        RsDt  RsDays capTime
# ...

# %%
nonfno_df.head()
# Out:
#          Stock  dly_RTO  prchg%  qty_rto     High  cur_dly  cur_trd_qty  \
# 43  SHARDACROP    13.10   13.58    29.63  1000.00   876575      4231467
# 21    FIVESTAR     9.15  -11.63    16.90   501.40  3410437     10772644
# 23       GLAND     8.74    6.71    33.77  1847.10   490396      2850641
# 27  HERITGFOOD     7.63   -8.28     8.47   374.00   776146      1621481
# 39        RAIN     7.08   13.16    16.06   169.63  8122935     32040642
#
#       Tval    Tvol      LTP      Low     VWAP   prchg  pRange   Val_CR  \
# 43  501.73   52.97   988.85   829.05   947.18  118.25  170.95  584.354
# 21  510.15  111.88   443.00   435.05   455.96  -58.30   66.35  546.078
# 23  533.65   29.60  1803.10  1745.70  1802.94  113.40  101.40  555.944
# 27   60.49   16.66   363.80   358.20   363.11  -32.85   15.80   64.867
# 39  576.99  353.61   163.69   143.50   163.17   19.04   26.13  627.214
#
#          Vol  DlyAvg_10        RsDt  RsDays capTime
# 43   6137931    66910.9  2026-01-29  0 days   15:00
# ...

# %%
from kiteconnect import KiteConnect
import logging

# %%
logging.basicConfig(level=logging.DEBUG)

# %%
opcol = ['Date', 'clienttype', 'opidxcalllong', 'opcalllong_pct', 'opidxcallshort','opcallshort_pct',
         'opidxputlong','opputlong_pct', 'opidxputshort', 'opputshort_pct', 'noofcons', 'Trdvalrscrs']
opcol = ['Date', 'clienttype', 'opidxcalllong', 'opidxcallshort','opcalllong_pct', 'opcallshort_pct','opputlong_pct','opputshort_pct','opidxputshort', 
         'opidxputlong', 'noofcons', 'Trdvalrscrs']

# %%
fuidx_pct_vol.head(5)
# Out:
#          Date clienttype  fuidxlong  fuidxshort  fuidxlong_pct  \
# 0  2026-02-16     Client      57605       60760          48.53
# 1  2026-02-16        DII       1036           0           0.87
# 2  2026-02-16        FII      16047       13612          13.52
# 3  2026-02-16        Pro      44009       44325          37.08
# 4  2026-02-16      TOTAL     118697      118697         100.00
#
#    fuidxshort_pct  conavg_lac  Pbaselong_cr  Pbaseshort_cr  \
# 0           51.19      17.111       9856.42       10396.66
# 1            0.00      17.111        176.70           0.00
# 2           11.47      17.111       2745.91        2329.55
# 3           37.34      17.111       7530.93        7583.74
# 4          100.00      17.111      20309.95       20309.95
#
#    long_AvgbaseAmt_cr  short_AvgbaseAmt_cr  noofcons  Trdvalrscrs
# 0            9856.792            10396.644  118697.0     20309.95
# 1             177.270                0.000  118697.0     20309.95
# ...

# %%
opidx_pct_oi.head(5)
# Out:
#          Date clienttype  opidxcalllong  opidxputshort  opidxputlong  \
# 0  2026-02-16     Client        3089315        3487722       3078014
# 1  2026-02-16        DII           1077            200         56917
# 2  2026-02-16        FII         712009         712479       1040807
# 3  2026-02-16        Pro        1233135        1404451       1429115
# 4  2026-02-16      TOTAL        5035537        5604852       5604852
#
#    opidxcallshort  opcalllong_pct  opputshort_pct  opputlong_pct  \
# 0         3220939           61.35           62.23          54.92
# 1             200            0.02            0.00           1.02
# 2          676107           14.14           12.71          18.57
# 3         1138290           24.49           25.06          25.50
# 4         5035537          100.00          100.00         100.00
#
#    opcallshort_pct     noofcons  Trdvalrscrs
# 0            63.96  158865726.0  26515027.41
# 1             0.00  158865726.0  26515027.41
# ...

# %%
fuidx_with_total.head()
# Out:
#             Date      symbol  noofconsTrd   TrdQty  totTrdvalrsincrs  \
# 1175  2026-02-16       TOTAL       118697  6766150          20309.94
# 3     2026-02-16  NIFTYNXT50          469    11725             81.19
# 4     2026-02-16  NIFTY             77439  5033535          12902.66
# 2     2026-02-16  MIDCPNIFTY         5399   647880            881.72
# 1     2026-02-16  FINNIFTY            377    22620             63.82
#
#       OIqtyasatendoftradinghrs
# 1175                  21678940
# 3                        20350
# 4                     17731740
# 2                      2225160
# 1                        48000

# %%
fno.head(5)
# Out:
#          Date          product   noofcons  Trdvalrscrs
# 0  2026-02-16  Index Futures       118697     20309.95
# 1  2026-02-16  Stock Futures      1219236     82461.95
# 2  2026-02-16  Index Options    158865726  26515027.41
# 3  2026-02-16  Stock Options      9083288    644080.68
# 4  2026-02-16  F&O Total        169286947  27261879.99

# %%
oi.head(3)
# Out:
#          Date clienttype  fuidxlong  fuidxshort  fustocklong  fustockshort  \
# 0  2026-02-16     Client     148863       68617      2849715        326200
# 1  2026-02-16        DII     111287       33648       312524       4416748
# 2  2026-02-16        FII      48627      193765      3877753       2640847
#
#    opidxcalllong  opidxputlong  opidxcallshort  opidxputshort  \
# 0        3089315       3078014         3220939        3487722
# 1           1077         56917             200            200
# 2         712009       1040807          676107         712479
#
#    opstockcalllong  opstockputlong  opstockcallshort  opstockputshort  \
# 0          2727051         1055592           1484216          1213444
# 1             1684           35732            469120             2340
# 2           231066          283270            331783           250778
#
#    totlongcons  totshortcons
# 0     12948550       9801138
# 1       519221       4922256
# 2      6193532       4805759

# %%
vol.head(3)
# Out:
#          Date clienttype  fuidxlong  fuidxshort  fustocklong  fustockshort  \
# 0  2026-02-16     Client      57605       60760       334698        349064
# 1  2026-02-16        DII       1036           0        70995         64294
# 2  2026-02-16        FII      16047       13612       304704        298837
#
#    opidxcalllong  opidxputlong  opidxcallshort  opidxputshort  \
# 0       32087799      26072647        32230061       25924054
# 1              0           330               0           1700
# 2        5894122       5429367         5885927        5472039
#
#    opstockcalllong  opstockputlong  opstockcallshort  opstockputshort  \
# 0          1859428          805658           1906616           791825
# 1             3015             352             12418               65
# 2           363112          193504            366387           194305
#
#    totlongcons  totshortcons
# 0     61217835      61262380
# 1        75728         78477
# 2     12200856      12231107

# %%
oi.columns
# Out:
# Index(['Date', 'clienttype', 'fuidxlong', 'fuidxshort', 'fustocklong',
#        'fustockshort', 'opidxcalllong', 'opidxputlong', 'opidxcallshort',
#        'opidxputshort', 'opstockcalllong', 'opstockputlong',
#        'opstockcallshort', 'opstockputshort', 'totlongcons', 'totshortcons'],
#       dtype='object')

# %%
vol.columns
# Out:
# Index(['Date', 'clienttype', 'fuidxlong', 'fuidxshort', 'fustocklong',
#        'fustockshort', 'opidxcalllong', 'opidxputlong', 'opidxcallshort',
#        'opidxputshort', 'opstockcalllong', 'opstockputlong',
#        'opstockcallshort', 'opstockputshort', 'totlongcons', 'totshortcons'],
#       dtype='object')

# %%
fuidx_col = ['Date', 'clienttype', 'fuidxlong', 'fuidxshort']
fustk_col = ['Date', 'clienttype', 'fustocklong', 'fustockshort']
opidx_col = ['Date', 'clienttype', 'opidxcalllong', 'opidxputshort','opidxputlong', 'opidxcallshort']
opstk_col = ['Date', 'clienttype', 'opstockcalllong', 'opstockputshort', 'opstockputlong', 'opstockcallshort']

# %%
oi_fuidx = oi[fuidx_col]
oi_fustk = oi[fustk_col]
oi_opidx = oi[opidx_col]
oi_opstk = oi[opstk_col]

# %%
vol_fuidx = vol[fuidx_col]
vol_fustk = vol[fustk_col]
vol_opidx = vol[opidx_col]
vol_opstk = vol[opstk_col]

# %%
oi_fuidx.head()
# Out:
#          Date clienttype  fuidxlong  fuidxshort
# 0  2026-02-17     Client     152575       70061
# 1  2026-02-17        DII     109813       34029
# 2  2026-02-17        FII      52273      193531
# 3  2026-02-17        Pro      37222       54262
# 4  2026-02-17      TOTAL     351883      351883

# %%
vol_opidx.head()
# Out:
#          Date clienttype  opidxcalllong  opidxputshort  opidxputlong  \
# 0  2026-02-17     Client       70061820       62847766      62947216
# 1  2026-02-17        DII              0           3400             0
# 2  2026-02-17        FII       11498775       10725964      10624322
# 3  2026-02-17        Pro      134743914      132337021     132342613
# 4  2026-02-17      TOTAL      216304509      205914151     205914151
#
#    opidxcallshort
# 0        70176143
# 1               0
# 2        11529991
# 3       134598375
# 4       216304509

# %%
vol_opidx = vol_opidx.copy()
vol_opidx['TotOpLong'] = vol_opidx['opidxcalllong'] + vol_opidx['opidxputshort']
vol_opidx['TotOpShort'] = vol_opidx['opidxputlong'] + vol_opidx['opidxcallshort']

# %%
vol_opidx.head()
# Out:
#          Date clienttype  opidxcalllong  opidxputshort  opidxputlong  \
# 0  2026-02-17     Client       70061820       62847766      62947216
# 1  2026-02-17        DII              0           3400             0
# 2  2026-02-17        FII       11498775       10725964      10624322
# 3  2026-02-17        Pro      134743914      132337021     132342613
# 4  2026-02-17      TOTAL      216304509      205914151     205914151
#
#    opidxcallshort  TotOpLong  TotOpShort
# 0        70176143  132909586   133123359
# 1               0       3400           0
# 2        11529991   22224739    22154313
# 3       134598375  267080935   266940988
# 4       216304509  422218660   422218660

# %%
fno.head()
# Out:
#          Date          product   noofcons  Trdvalrscrs    AvgVal_lac
# 0  2026-02-17  Index Futures       105750     18098.41  17114.335697
# 1  2026-02-17  Stock Futures      1536843    103106.47   6708.978731
# 2  2026-02-17  Index Options    422218660  70617765.00  16725.401241
# 3  2026-02-17  Stock Options      9519473    664653.04   6982.036085
# 4  2026-02-17  F&O Total        433380726  71403622.92  16475.957198

# %%
vol_opstk.head()
# Out:
#          Date clienttype  opstockcalllong  opstockputshort  opstockputlong  \
# 0  2026-02-17     Client          1966901           797187          785034
# 1  2026-02-17        DII             3173             1524             756
# 2  2026-02-17        FII           446091           229802          235935
# 3  2026-02-17        Pro          3926735          2148060         2154848
# 4  2026-02-17      TOTAL          6342900          3176573         3176573
#
#    opstockcallshort
# 0           1990236
# 1             11670
# 2            444226
# 3           3896768
# 4           6342900

# %%
vol_opstk = vol_opstk.copy()
vol_opstk['TotOpLong'] = vol_opstk['opstockcalllong'] + vol_opstk['opstockputshort']
vol_opstk['TotOpShort'] = vol_opstk['opstockputlong'] + vol_opstk['opstockcallshort']
vol_opstk.head()
# Out:
#          Date clienttype  opstockcalllong  opstockputshort  opstockputlong  \
# 0  2026-02-17     Client          1966901           797187          785034
# 1  2026-02-17        DII             3173             1524             756
# 2  2026-02-17        FII           446091           229802          235935
# 3  2026-02-17        Pro          3926735          2148060         2154848
# 4  2026-02-17      TOTAL          6342900          3176573         3176573
#
#    opstockcallshort  TotOpLong  TotOpShort
# 0           1990236    2764088     2775270
# 1             11670       4697       12426
# 2            444226     675893      680161
# 3           3896768    6074795     6051616
# 4           6342900    9519473     9519473

# %%
# Assuming your dataframe is called oi_fuidx
# First, isolate the TOTAL values per Date
totals = oi_fuidx[oi_fuidx['clienttype'] == 'TOTAL'][['Date','fuidxlong','fuidxshort']]
totals = totals.rename(columns={'fuidxlong':'total_long','fuidxshort':'total_short'})

# Merge totals back into the main dataframe
df = oi_fuidx.merge(totals, on='Date')

# Calculate percentages
df['fuidxlng_pct'] = round((df['fuidxlong'] / df['total_long']) * 100, 2)
df['fuidxsht_pct'] = round((df['fuidxshort'] / df['total_short']) * 100, 2)

# Optional: drop TOTAL row if you only want client breakdowns
result = df[df['clienttype'] != 'TOTAL']
result.head()
# Out:
#          Date clienttype  fuidxlong  fuidxshort  total_long  total_short  \
# 0  2026-02-17     Client     152575       70061      351883       351883
# 1  2026-02-17        DII     109813       34029      351883       351883
# 2  2026-02-17        FII      52273      193531      351883       351883
# 3  2026-02-17        Pro      37222       54262      351883       351883
# 5  2026-02-16     Client     148863       68617      347729       347729
#
#    fuidxlng_pct  fuidxsht_pct
# 0         43.36         19.91
# 1         31.21          9.67
# 2         14.86         55.00
# 3         10.58         15.42
# 5         42.81         19.73

# %%
oi_opidx.head(5)
# Out:
#          Date clienttype  opidxcalllong  opidxputshort  opidxputlong  \
# 0  2026-02-17     Client        1741236        2059356       1803932
# 1  2026-02-17        DII           1077            200         53517
# 2  2026-02-17        FII         471139         468495        769873
# 3  2026-02-17        Pro         662640         802055        702783
# 4  2026-02-17      TOTAL        2876092        3330106       3330106
#
#    opidxcallshort
# 0         1818876
# 1             200
# 2          441781
# 3          615234
# 4         2876092

# %%
oi_opidx = oi_opidx.copy()
oi_opidx['TotOpLong'] = oi_opidx['opidxcalllong'] + oi_opidx['opidxputshort']
oi_opidx['TotOpShort'] = oi_opidx['opidxputlong'] + oi_opidx['opidxcallshort']

# %%
oi_opidx.head()
# Out:
#          Date clienttype  opidxcalllong  opidxputshort  opidxputlong  \
# 0  2026-02-17     Client        1741236        2059356       1803932
# 1  2026-02-17        DII           1077            200         53517
# 2  2026-02-17        FII         471139         468495        769873
# 3  2026-02-17        Pro         662640         802055        702783
# 4  2026-02-17      TOTAL        2876092        3330106       3330106
#
#    opidxcallshort  TotOpLong  TotOpShort
# 0         1818876    3800592     3622808
# 1             200       1277       53717
# 2          441781     939634     1211654
# 3          615234    1464695     1318017
# 4         2876092    6206198     6206198

# %%
# Calculate percentages
oi_opidx = oi_opidx.copy()
oi_opidx['TotOpLong'] = oi_opidx['opidxcalllong'] + oi_opidx['opidxputshort']
oi_opidx['TotOpShort'] = oi_opidx['opidxputlong'] + oi_opidx['opidxcallshort']
oi_opidx['opidxlng_pct'] = round((oi_opidx['TotOpLong'] / (oi_opidx['TotOpLong'] + oi_opidx['TotOpShort'])) * 100, 2)
oi_opidx['opidxsht_pct'] = round((oi_opidx['TotOpShort'] / (oi_opidx['TotOpLong'] + oi_opidx['TotOpShort'])) * 100, 2)

# %%
oi_opidx.head()
# Out:
#          Date clienttype  opidxcalllong  opidxputshort  opidxputlong  \
# 0  2026-02-17     Client        1741236        2059356       1803932
# 1  2026-02-17        DII           1077            200         53517
# 2  2026-02-17        FII         471139         468495        769873
# 3  2026-02-17        Pro         662640         802055        702783
# 4  2026-02-17      TOTAL        2876092        3330106       3330106
#
#    opidxcallshort  TotOpLong  TotOpShort  lng_pct  sht_pct  opidxlng_pct  \
# 0         1818876    3800592     3622808    51.20    48.80         51.20
# 1             200       1277       53717     2.32    97.68          2.32
# 2          441781     939634     1211654    43.68    56.32         43.68
# 3          615234    1464695     1318017    52.64    47.36         52.64
# 4         2876092    6206198     6206198    50.00    50.00         50.00
#
#    opidxsht_pct
# 0         48.80
# 1         97.68
# 2         56.32
# 3         47.36
# 4         50.00

# %%
oi_fuidx.head()
# Out:
#          Date clienttype  fuidxlong  fuidxshort
# 0  2026-02-17     Client     152575       70061
# 1  2026-02-17        DII     109813       34029
# 2  2026-02-17        FII      52273      193531
# 3  2026-02-17        Pro      37222       54262
# 4  2026-02-17      TOTAL     351883      351883

# %%
oi_fuidx = oi_fuidx.copy()
oi_fuidx['fuidxlng_pct'] = round(oi_fuidx['fuidxlong'] / (oi_fuidx['fuidxlong'] + oi_fuidx['fuidxshort']) * 100, 2)
oi_fuidx['fuidxsht_pct'] = round(oi_fuidx['fuidxshort'] / (oi_fuidx['fuidxlong'] + oi_fuidx['fuidxshort']) * 100, 2)

# %%
oi_fuidx.head()
# Out:
#          Date clienttype  fuidxlong  fuidxshort  fuidxlng_pct  fuidxsht_pct
# 0  2026-02-17     Client     152575       70061         68.53         31.47
# 1  2026-02-17        DII     109813       34029         76.34         23.66
# 2  2026-02-17        FII      52273      193531         21.27         78.73
# 3  2026-02-17        Pro      37222       54262         40.69         59.31
# 4  2026-02-17      TOTAL     351883      351883         50.00         50.00

# %%
oi_opidx.head()
# Out:
#          Date clienttype  opidxcalllong  opidxputshort  opidxputlong  \
# 0  2026-02-17     Client        1741236        2059356       1803932
# 1  2026-02-17        DII           1077            200         53517
# 2  2026-02-17        FII         471139         468495        769873
# 3  2026-02-17        Pro         662640         802055        702783
# 4  2026-02-17      TOTAL        2876092        3330106       3330106
#
#    opidxcallshort  TotOpLong  TotOpShort  opidxlng_pct  opidxsht_pct
# 0         1818876    3800592     3622808         51.20         48.80
# 1             200       1277       53717          2.32         97.68
# 2          441781     939634     1211654         43.68         56.32
# 3          615234    1464695     1318017         52.64         47.36
# 4         2876092    6206198     6206198         50.00         50.00

# %%
oi_fnoidx_pct[oi_fnoidx_pct['clienttype'] == 'Pro'].head(21)
# Out:
#            Date clienttype  fuidxlng_pct  fuidxsht_pct  opidxlng_pct  \
# 3    2026-02-17        Pro         40.69         59.31         52.64
# 8    2026-02-16        Pro         42.97         57.03         50.67
# 13   2026-02-13        Pro         43.18         56.82         48.22
# 18   2026-02-12        Pro         38.26         61.74         49.08
# 23   2026-02-11        Pro         32.84         67.16         51.12
# 28   2026-02-10        Pro         28.34         71.66         51.71
# 33   2026-02-06        Pro         26.60         73.40         50.96
# 38   2026-02-05        Pro         25.44         74.56         49.79
# 43   2026-02-04        Pro         30.92         69.08         51.66
# 48   2026-02-03        Pro         29.47         70.53         49.58
# 53   2026-02-02        Pro         48.80         51.20         48.89
# 58   2026-02-01        Pro         50.98         49.02         46.13
# 63   2026-01-30        Pro         42.40         57.60         48.54
# ...

# %% [markdown]
# ## Calculation OI and VOL for Stocks.

# %%
reorder = ['Date', 'symbol', 'ValPerQty', 'noofconsTrd', 'TrdQty','OIqtyasatendoftradinghrs', 'totTrdvalrsincrs', 'OI_eod_val_cr']
fuidx_val = fuidx_val[reorder]
fuidx_val.head(6)
# Out:
#          Date      symbol  ValPerQty  noofconsTrd   TrdQty  \
# 0  2026-02-17       TOTAL  29372.708       105750  6161645
# 1  2026-02-17  NIFTYNXT50  69714.286          217     5425
# 2  2026-02-17  NIFTY       25726.384        74684  4854460
# 3  2026-02-17  MIDCPNIFTY  13681.045         4115   493800
# 4  2026-02-17  FINNIFTY    28240.741          198    11880
# 5  2026-02-17  BANKNIFTY   61083.183        26536   796080
#
#    OIqtyasatendoftradinghrs  totTrdvalrsincrs  OI_eod_val_cr
# 0                  22019355          18098.42      64676.808
# 1                     21225             37.82        147.969
# 2                  17874480          12488.77      45984.574
# 3                   2307600            675.57       3157.038
# 4                     48540             33.55        137.081
# 5                   1767510           4862.71      10796.514

# %%
vol_fnoidx_pct.head(15)
# Out:
#           Date clienttype  fuidxlng_pct  fuidxsht_pct  opidxlng_pct  \
# 0   2026-02-17     Client         51.10         48.90         49.96
# 1   2026-02-17        DII         25.65         74.35        100.00
# 2   2026-02-17        FII         57.33         42.67         50.08
# 3   2026-02-17        Pro         47.26         52.74         50.01
# 4   2026-02-17      TOTAL         50.00         50.00         50.00
# 5   2026-02-16     Client         48.67         51.33         49.87
# 6   2026-02-16        DII        100.00          0.00         83.74
# 7   2026-02-16        FII         54.10         45.90         50.11
# 8   2026-02-16        Pro         49.82         50.18         50.07
# 9   2026-02-16      TOTAL         50.00         50.00         50.00
# 10  2026-02-13     Client         52.59         47.41         50.10
# 11  2026-02-13        DII         59.76         40.24        100.00
# 12  2026-02-13        FII         30.73         69.27         49.76
# ...

# %%
import pandas as pd
from datetime import datetime
import sqlite3
import os 

print("The Task start at ", datetime.now())

BASE_DIR_db = "/home/shail/db"
db_path = os.path.join(BASE_DIR_db, "fnodailydata.db")

# --- Load all tables into dictionary ---
with sqlite3.connect(db_path) as conn:
    tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
    dfs = {}
    for name in tables['name']:
        df = pd.read_sql_query(f'SELECT * FROM "{name}" ORDER BY Date DESC', conn)
        df = df.drop_duplicates()
        df['Date'] = pd.to_datetime(df['Date'])
        dfs[name] = df

# Unpack
fii, fno, fuidx, fustk, oi, vol = dfs['fii'], dfs['fnototal'], dfs['fuidx'], dfs['fustk'], dfs['participant_oi'], dfs['participant_vol']

# Column definitions
fuidx_col = ['Date', 'clienttype', 'fuidxlong', 'fuidxshort']
opidx_col = ['Date', 'clienttype', 'opidxcalllong', 'opidxputshort','opidxputlong', 'opidxcallshort']
# Column Stock definitions
fustock_col = ['Date', 'clienttype', 'fustocklong', 'fustockshort']
opstock_col = ['Date', 'clienttype', 'opstockcalllong', 'opstockputshort','opstockputlong', 'opstockcallshort']

def calc_stock_pct(df, fustock_col, opstock_col):
    # --- Futures Index ---
    fustock = df[fustock_col].copy()
    fustock_pct = fustock[['Date','clienttype','fustocklong','fustockshort']]

    # --- Options Index ---
    opstock = df[opstock_col].copy()
    opstock['TotOpLong'] = opstock['opstockcalllong'] + opstock['opstockputshort']
    opstock['TotOpShort'] = opstock['opstockputlong'] + opstock['opstockcallshort']
    opstock_pct = opstock[['Date','clienttype','TotOpLong','TotOpShort']]

    # Merge futures + options
    merged = pd.merge(fustock_pct, opstock_pct, on=['Date','clienttype'], how='inner')

    # Extract TOTAL rows for each date
    totals = merged[merged['clienttype'] == 'TOTAL'].rename(columns={
        'fustocklong':'fustocklong_TOTAL',
        'fustockshort':'fustockshort_TOTAL',
        'TotOpLong':'TotOpLong_TOTAL',
        'TotOpShort':'TotOpShort_TOTAL'
    })[['Date','fustocklong_TOTAL','fustockshort_TOTAL','TotOpLong_TOTAL','TotOpShort_TOTAL']]

    # Join TOTAL values back to all rows
    merged = merged.merge(totals, on='Date', how='left')

    # --- Percentages relative to TOTAL row ---
    # Futures
    merged['fustocklng_pct'] = (merged['fustocklong'] / merged['fustocklong_TOTAL'] * 100).round(2)
    merged['fustocksht_pct'] = (merged['fustockshort'] / merged['fustockshort_TOTAL'] * 100).round(2)

    # Options
    merged['opstocklng_pct'] = (merged['TotOpLong'] / merged['TotOpLong_TOTAL'] * 100).round(2)
    merged['opstocksht_pct'] = (merged['TotOpShort'] / merged['TotOpShort_TOTAL'] * 100).round(2)

    # Final cleanup — sort descending by Date
    final = merged[['Date','clienttype',
                    'fustocklng_pct','fustocksht_pct',
                    'opstocklng_pct','opstocksht_pct']] \
            .sort_values(['Date','clienttype'], ascending=[False, True])

    return final


def calc_pct(df, fuidx_col, opidx_col):
    # --- Futures Index ---
    fuidx = df[fuidx_col].copy()
    fuidx_pct = fuidx[['Date','clienttype','fuidxlong','fuidxshort']]

    # --- Options Index ---
    opidx = df[opidx_col].copy()
    opidx['TotOpLong'] = opidx['opidxcalllong'] + opidx['opidxputshort']
    opidx['TotOpShort'] = opidx['opidxputlong'] + opidx['opidxcallshort']
    opidx_pct = opidx[['Date','clienttype','TotOpLong','TotOpShort']]

    # Merge futures + options
    merged = pd.merge(fuidx_pct, opidx_pct, on=['Date','clienttype'], how='inner')

    # Extract TOTAL rows for each date
    totals = merged[merged['clienttype'] == 'TOTAL'].rename(columns={
        'fuidxlong':'fuidxlong_TOTAL',
        'fuidxshort':'fuidxshort_TOTAL',
        'TotOpLong':'TotOpLong_TOTAL',
        'TotOpShort':'TotOpShort_TOTAL'
    })[['Date','fuidxlong_TOTAL','fuidxshort_TOTAL','TotOpLong_TOTAL','TotOpShort_TOTAL']]

    # Join TOTAL values back to all rows
    merged = merged.merge(totals, on='Date', how='left')

    # --- Percentages relative to TOTAL row ---
    # Futures
    merged['fuidxlng_pct'] = (merged['fuidxlong'] / merged['fuidxlong_TOTAL'] * 100).round(2)
    merged['fuidxsht_pct'] = (merged['fuidxshort'] / merged['fuidxshort_TOTAL'] * 100).round(2)

    # Options
    merged['opidxlng_pct'] = (merged['TotOpLong'] / merged['TotOpLong_TOTAL'] * 100).round(2)
    merged['opidxsht_pct'] = (merged['TotOpShort'] / merged['TotOpShort_TOTAL'] * 100).round(2)

    # Final cleanup — sort descending by Date
    final = merged[['Date','clienttype',
                    'fuidxlng_pct','fuidxsht_pct',
                    'opidxlng_pct','opidxsht_pct']] \
            .sort_values(['Date','clienttype'], ascending=[False, True])

    return final


# Apply to both oi and vol
oi_fnoidx_pct = calc_pct(oi, fuidx_col, opidx_col)
vol_fnoidx_pct = calc_pct(vol, fuidx_col, opidx_col)
oi_fnoidx_pct['fuidxnet'] = oi_fnoidx_pct['fuidxlng_pct'] - oi_fnoidx_pct['fuidxsht_pct']
oi_fnoidx_pct['opidxnet'] = oi_fnoidx_pct['opidxlng_pct'] - oi_fnoidx_pct['opidxsht_pct']
vol_fnoidx_pct['fuidxnet'] = vol_fnoidx_pct['fuidxlng_pct'] - vol_fnoidx_pct['fuidxsht_pct']
vol_fnoidx_pct['opidxnet'] = vol_fnoidx_pct['opidxlng_pct'] - vol_fnoidx_pct['opidxsht_pct']

# Apply to Stock oi and vol
oi_fnostock_pct =  calc_stock_pct(oi, fustock_col, opstock_col)
vol_fnostock_pct =  calc_stock_pct(vol, fustock_col, opstock_col)
oi_fnostock_pct['fustocknet'] = oi_fnostock_pct['fustocklng_pct'] - oi_fnostock_pct['fustocksht_pct']
oi_fnostock_pct['opstocknet'] = oi_fnostock_pct['opstocklng_pct'] - oi_fnostock_pct['opstocksht_pct']
vol_fnostock_pct['fustocknet'] = vol_fnostock_pct['fustocklng_pct'] - vol_fnostock_pct['fustocksht_pct']
vol_fnostock_pct['opstocknet'] = vol_fnostock_pct['opstocklng_pct'] - vol_fnostock_pct['opstocksht_pct']
# Merge fuidx_vol with fno to bring in Index Futures values for the same Date

print("The Task Completed Successfully at ", datetime.now())
# Out:
# The Task start at  2026-02-18 02:47:28.241379
# The Task Completed Successfully at  2026-02-18 02:47:28.396150

# %%
oi_fnostock_pct.head()
# Out:
#         Date clienttype  fustocklng_pct  fustocksht_pct  opstocklng_pct  \
# 0 2026-02-17     Client           35.82            4.17           56.40
# 1 2026-02-17        DII            4.00           54.82            0.07
# 2 2026-02-17        FII           48.50           33.44            7.03
# 3 2026-02-17        Pro           11.68            7.57           36.50
# 4 2026-02-17      TOTAL          100.00          100.00          100.00
#
#    opstocksht_pct  fustocknet  opstocknet
# 0           36.52       31.65       19.88
# 1            7.35      -50.82       -7.28
# 2            9.00       15.06       -1.97
# 3           47.13        4.11      -10.63
# 4          100.00        0.00        0.00

# %%
vol_fnoidx_pct.head()
# Out:
#         Date clienttype  fuidxlng_pct  fuidxsht_pct  opidxlng_pct  \
# 0 2026-02-17     Client         49.77         47.63         31.48
# 1 2026-02-17        DII          0.92          2.68          0.00
# 2 2026-02-17        FII         14.35         10.68          5.26
# 3 2026-02-17        Pro         34.96         39.02         63.26
# 4 2026-02-17      TOTAL        100.00        100.00        100.00
#
#    opidxsht_pct  fuidxnet  opidxnet
# 0         31.53      2.14     -0.05
# 1          0.00     -1.76      0.00
# 2          5.25      3.67      0.01
# 3         63.22     -4.06      0.04
# 4        100.00      0.00      0.00

# %%
fii.head()
# Out:
#         Date             Product  Buy_Contracts  Buy_Amt_Cr  Sell_Contracts  \
# 0 2026-02-17       INDEX FUTURES        15171.0     2630.98         11291.0
# 1 2026-02-17   BANKNIFTY FUTURES         5805.0     1066.41          3331.0
# 2 2026-02-17    FINNIFTY FUTURES           10.0        1.69            18.0
# 3 2026-02-17  MIDCPNIFTY FUTURES          445.0       73.05          1216.0
# 4 2026-02-17       NIFTY FUTURES         8869.0     1482.50          6686.0
#
#    Sell_Amt_Cr  OI_Contracts  OI_Amt_Cr  NetAmt_cr  Netcon
# 0      1936.44      245804.0   41631.75     694.54  3880.0
# 1       609.52       34746.0    6377.82     456.89  2474.0
# 2         3.05         414.0      70.21      -1.36    -8.0
# 3       199.46       23776.0    3900.60    -126.41  -771.0
# 4      1117.45      186339.0   31190.81     365.05  2183.0

# %%
fno['product'] = fno['product'].str.strip()
idx_fut = fno[fno['product'] == 'Index Futures'][['Date','noofcons','Trdvalrscrs']]
fuidx_vol = vol_fnoidx_pct.merge(idx_fut, on='Date', how='left')
fuidx_vol['long_amt_cr'] = (fuidx_vol['fuidxlng_pct'] / 100 * fuidx_vol['Trdvalrscrs']).round(4)
fuidx_vol['short_amt_cr'] = (fuidx_vol['fuidxsht_pct'] / 100 * fuidx_vol['Trdvalrscrs']).round(4)
fuidx_vol['net_amt_cr'] = fuidx_vol['long_amt_cr'] - fuidx_vol['short_amt_cr']
newcol = ['Date', 'clienttype', 'fuidxlng_pct', 'fuidxsht_pct', 'opidxlng_pct',
       'opidxsht_pct', 'fuidxnet', 'opidxnet',
       'long_amt_cr', 'short_amt_cr', 'net_amt_cr']
fuidx_vol = fuidx_vol[newcol]

# %%
fuidx_vol.head()
# Out:
#         Date clienttype  fuidxlng_pct  fuidxsht_pct  opidxlng_pct  \
# 0 2026-02-17     Client         49.77         47.63         31.48
# 1 2026-02-17        DII          0.92          2.68          0.00
# 2 2026-02-17        FII         14.35         10.68          5.26
# 3 2026-02-17        Pro         34.96         39.02         63.26
# 4 2026-02-17      TOTAL        100.00        100.00        100.00
#
#    opidxsht_pct  fuidxnet  opidxnet  long_amt_cr  short_amt_cr  net_amt_cr
# 0         31.53      2.14     -0.05    9007.5787     8620.2727    387.3060
# 1          0.00     -1.76      0.00     166.5054      485.0374   -318.5320
# 2          5.25      3.67      0.01    2597.1218     1932.9102    664.2116
# 3         63.22     -4.06      0.04    6327.2041     7061.9996   -734.7955
# 4        100.00      0.00      0.00   18098.4100    18098.4100      0.0000

# %%
fuidx_vol.columns
newcol = ['Date', 'clienttype', 'fuidxlng_pct', 'fuidxsht_pct', 'opidxlng_pct',
       'opidxsht_pct', 'fuidxnet', 'opidxnet',
       'long_amt_cr', 'short_amt_cr', 'net_amt_cr']
fuidx_vol = fuidx_vol[newcol]
# Out:
# Index(['Date', 'clienttype', 'fuidxlng_pct', 'fuidxsht_pct', 'opidxlng_pct',
#        'opidxsht_pct', 'fuidxnet', 'opidxnet', 'noofcons', 'Trdvalrscrs',
#        'long_amt_cr', 'short_amt_cr', 'net_amt_cr'],
#       dtype='object')

# %%
# Join on Date vol_fnostock_pct
fuidx_vol = vol_fnoidx_pct.merge(idx_fut, on='Date', how='left')
fuidx_vol.head()
# Out:
#         Date clienttype  fuidxlng_pct  fuidxsht_pct  opidxlng_pct  \
# 0 2026-02-17     Client         49.77         47.63         31.48
# 1 2026-02-17        DII          0.92          2.68          0.00
# 2 2026-02-17        FII         14.35         10.68          5.26
# 3 2026-02-17        Pro         34.96         39.02         63.26
# 4 2026-02-17      TOTAL        100.00        100.00        100.00
#
#    opidxsht_pct  fuidxnet  opidxnet  noofcons  Trdvalrscrs
# 0         31.53      2.14     -0.05  105750.0     18098.41
# 1          0.00     -1.76      0.00  105750.0     18098.41
# 2          5.25      3.67      0.01  105750.0     18098.41
# 3         63.22     -4.06      0.04  105750.0     18098.41
# 4        100.00      0.00      0.00  105750.0     18098.41

# %%
fuidx_vol.head()
# Out:
#         Date clienttype  fuidxlng_pct  fuidxsht_pct  opidxlng_pct  \
# 0 2026-02-17     Client         49.77         47.63         31.48
# 1 2026-02-17        DII          0.92          2.68          0.00
# 2 2026-02-17        FII         14.35         10.68          5.26
# 3 2026-02-17        Pro         34.96         39.02         63.26
# 4 2026-02-17      TOTAL        100.00        100.00        100.00
#
#    opidxsht_pct  fuidxnet  opidxnet  noofcons  Trdvalrscrs
# 0         31.53      2.14     -0.05  105750.0     18098.41
# 1          0.00     -1.76      0.00  105750.0     18098.41
# 2          5.25      3.67      0.01  105750.0     18098.41
# 3         63.22     -4.06      0.04  105750.0     18098.41
# 4        100.00      0.00      0.00  105750.0     18098.41

# %%
# Calculate Pbaselong_cr and Pbaseshort_cr using dynamic total_val
fuidx_vol['long_amt_cr'] = (fuidx_vol['fuidxlng_pct'] / 100 * fuidx_vol['Trdvalrscrs']).round(3)
fuidx_vol['short_amt_cr'] = (fuidx_vol['fuidxsht_pct'] / 100 * fuidx_vol['Trdvalrscrs']).round(3)
fuidx_vol.head()
# Out:
#         Date clienttype  fuidxlng_pct  fuidxsht_pct  opidxlng_pct  \
# 0 2026-02-17     Client         49.77         47.63         31.48
# 1 2026-02-17        DII          0.92          2.68          0.00
# 2 2026-02-17        FII         14.35         10.68          5.26
# 3 2026-02-17        Pro         34.96         39.02         63.26
# 4 2026-02-17      TOTAL        100.00        100.00        100.00
#
#    opidxsht_pct  fuidxnet  opidxnet  noofcons  Trdvalrscrs  long_amt_cr  \
# 0         31.53      2.14     -0.05  105750.0     18098.41     9007.579
# 1          0.00     -1.76      0.00  105750.0     18098.41      166.505
# 2          5.25      3.67      0.01  105750.0     18098.41     2597.122
# 3         63.22     -4.06      0.04  105750.0     18098.41     6327.204
# 4        100.00      0.00      0.00  105750.0     18098.41    18098.410
#
#    short_amt_cr
# 0      8620.273
# 1       485.037
# 2      1932.910
# 3      7062.000
# 4     18098.410

# %%
fuidx_vol['net_amt_cr'] = fuidx_vol['long_amt_cr'] - fuidx_vol['short_amt_cr']
fuidx_vol.head()
# Out:
#         Date clienttype  fuidxlng_pct  fuidxsht_pct  opidxlng_pct  \
# 0 2026-02-17     Client         49.77         47.63         31.48
# 1 2026-02-17        DII          0.92          2.68          0.00
# 2 2026-02-17        FII         14.35         10.68          5.26
# 3 2026-02-17        Pro         34.96         39.02         63.26
# 4 2026-02-17      TOTAL        100.00        100.00        100.00
#
#    opidxsht_pct  fuidxnet  opidxnet  noofcons  Trdvalrscrs  long_amt_cr  \
# 0         31.53      2.14     -0.05  105750.0     18098.41     9007.579
# 1          0.00     -1.76      0.00  105750.0     18098.41      166.505
# 2          5.25      3.67      0.01  105750.0     18098.41     2597.122
# 3         63.22     -4.06      0.04  105750.0     18098.41     6327.204
# 4        100.00      0.00      0.00  105750.0     18098.41    18098.410
#
#    short_amt_cr  net_amt_cr
# 0      8620.273     387.306
# 1       485.037    -318.532
# 2      1932.910     664.212
# ...

# %%
fii['Product']= fii['Product'].str.strip()

# %%
vol.head()
# Out:
#         Date clienttype  fuidxlong  fuidxshort  fustocklong  fustockshort  \
# 0 2026-02-17     Client      52634       50366       452866        445360
# 1 2026-02-17        DII        977        2832       199807        160033
# 2 2026-02-17        FII      15171       11291       341283        372984
# 3 2026-02-17        Pro      36968       41261       542887        558466
# 4 2026-02-17      TOTAL     105750      105750      1536843       1536843
#
#    opidxcalllong  opidxputlong  opidxcallshort  opidxputshort  \
# 0       70061820      62947216        70176143       62847766
# 1              0             0               0           3400
# 2       11498775      10624322        11529991       10725964
# 3      134743914     132342613       134598375      132337021
# 4      216304509     205914151       216304509      205914151
#
#    opstockcalllong  opstockputlong  opstockcallshort  opstockputshort  \
# 0          1966901          785034           1990236           797187
# ...

# %%
# totvolavg = Trdvalrscrs / noofcons (crores per contract), rounded to 3 decimals
fuidx_vol['conavg_lac'] = (fuidx_vol['Trdvalrscrs']*10000000 / fuidx_vol['noofcons']).round(5)
# Calculate AvgbaseAmt_cr using dynamic totvolavg
fuidx_vol['long_AvgbaseAmt_cr'] = vol['fuidxlong'] * 1711433.5697
fuidx_vol['short_AvgbaseAmt_cr'] = vol['fuidxshort'] * 1711433.5697
fuidx_vol.head()
# Out:
#         Date clienttype  fuidxlng_pct  fuidxsht_pct  opidxlng_pct  \
# 0 2026-02-17     Client         49.77         47.63         31.48
# 1 2026-02-17        DII          0.92          2.68          0.00
# 2 2026-02-17        FII         14.35         10.68          5.26
# 3 2026-02-17        Pro         34.96         39.02         63.26
# 4 2026-02-17      TOTAL        100.00        100.00        100.00
#
#    opidxsht_pct  fuidxnet  opidxnet  noofcons  Trdvalrscrs    conavg_lac  \
# 0         31.53      2.14     -0.05  105750.0     18098.41  1.711434e+06
# 1          0.00     -1.76      0.00  105750.0     18098.41  1.711434e+06
# 2          5.25      3.67      0.01  105750.0     18098.41  1.711434e+06
# 3         63.22     -4.06      0.04  105750.0     18098.41  1.711434e+06
# 4        100.00      0.00      0.00  105750.0     18098.41  1.711434e+06
#
#    long_AvgbaseAmt_cr  short_AvgbaseAmt_cr
# 0        9.007959e+10         8.619806e+10
# ...

# %%
fuidx_vol['Net_AvgbaseAmt_cr'] = fuidx_vol['long_AvgbaseAmt_cr'] - fuidx_vol['short_AvgbaseAmt_cr']
fuidx_vol.head()
# Out:
#         Date clienttype  fuidxlng_pct  fuidxsht_pct  opidxlng_pct  \
# 0 2026-02-17     Client         49.77         47.63         31.48
# 1 2026-02-17        DII          0.92          2.68          0.00
# 2 2026-02-17        FII         14.35         10.68          5.26
# 3 2026-02-17        Pro         34.96         39.02         63.26
# 4 2026-02-17      TOTAL        100.00        100.00        100.00
#
#    opidxsht_pct  fuidxnet  opidxnet  noofcons  Trdvalrscrs    conavg_lac  \
# 0         31.53      2.14     -0.05  105750.0     18098.41  1.711434e+06
# 1          0.00     -1.76      0.00  105750.0     18098.41  1.711434e+06
# 2          5.25      3.67      0.01  105750.0     18098.41  1.711434e+06
# 3         63.22     -4.06      0.04  105750.0     18098.41  1.711434e+06
# 4        100.00      0.00      0.00  105750.0     18098.41  1.711434e+06
#
#    long_AvgbaseAmt_cr  short_AvgbaseAmt_cr  Net_AvgbaseAmt_cr
# 0        9.007959e+10         8.619806e+10       3.881531e+09
# ...

# %%
fii.head()
# Out:
#         Date             Product  Buy_Contracts  Buy_Amt_Cr  Sell_Contracts  \
# 0 2026-02-17       INDEX FUTURES        15171.0     2630.98         11291.0
# 1 2026-02-17   BANKNIFTY FUTURES         5805.0     1066.41          3331.0
# 2 2026-02-17    FINNIFTY FUTURES           10.0        1.69            18.0
# 3 2026-02-17  MIDCPNIFTY FUTURES          445.0       73.05          1216.0
# 4 2026-02-17       NIFTY FUTURES         8869.0     1482.50          6686.0
#
#    Sell_Amt_Cr  OI_Contracts  OI_Amt_Cr  NetAmt_cr  Netcon
# 0      1936.44      245804.0   41631.75     694.54  3880.0
# 1       609.52       34746.0    6377.82     456.89  2474.0
# 2         3.05         414.0      70.21      -1.36    -8.0
# 3       199.46       23776.0    3900.60    -126.41  -771.0
# 4      1117.45      186339.0   31190.81     365.05  2183.0

# %%
fii['buy_avg_val'] = fii['Buy_Amt_Cr']*10000000 / fii['Buy_Contracts']
fii['sell_avg_val'] = fii['Sell_Amt_Cr']*10000000 / fii['Sell_Contracts']

# %%
fii.head()
# Out:
#         Date             Product  Buy_Contracts  Buy_Amt_Cr  Sell_Contracts  \
# 0 2026-02-17       INDEX FUTURES        15171.0     2630.98         11291.0
# 1 2026-02-17   BANKNIFTY FUTURES         5805.0     1066.41          3331.0
# 2 2026-02-17    FINNIFTY FUTURES           10.0        1.69            18.0
# 3 2026-02-17  MIDCPNIFTY FUTURES          445.0       73.05          1216.0
# 4 2026-02-17       NIFTY FUTURES         8869.0     1482.50          6686.0
#
#    Sell_Amt_Cr  OI_Contracts  OI_Amt_Cr  NetAmt_cr  Netcon       avg_val  \
# 0      1936.44      245804.0   41631.75     694.54  3880.0  1.734217e+06
# 1       609.52       34746.0    6377.82     456.89  2474.0  1.837054e+06
# 2         3.05         414.0      70.21      -1.36    -8.0  1.690000e+06
# 3       199.46       23776.0    3900.60    -126.41  -771.0  1.641573e+06
# 4      1117.45      186339.0   31190.81     365.05  2183.0  1.671553e+06
#
#     buy_avg_val  sell_avg_val
# 0  1.734217e+06  1.715030e+06
# ...

# %%
import requests
import pandas as pd
import io, zipfile
from datetime import datetime, timedelta
import sqlite3
import os 
import re

BASE_DIR_db = "/home/shail/db"
db_path = os.path.join(BASE_DIR_db, "fnodailydata.db")

# Connect to SQLite
conn = sqlite3.connect(db_path)

# Get list of all tables
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
table_names = tables['name'].tolist()

# Dictionary to hold DataFrames
dfs = {}

for name in table_names:
    try:
        query = f'SELECT * FROM "{name}" ORDER BY Date DESC'
        df = pd.read_sql_query(query, conn)
        dfs[name] = df
        print(f"Loaded table: {name}, rows: {len(df)}")
    except Exception as e:
        print(f"Skipped table {name} due to error: {e}")

conn.close()
fii = dfs['fii']
fno = dfs['fnototal']
fuidx = dfs['fuidx']
fustk = dfs['fustk']
oi = dfs['participant_oi']
vol = dfs['participant_vol']


# Select only the relevant columns from vol
fuidx_vol = vol[['Date', 'clienttype', 'fuidxlong','fuidxshort']].copy()

# Get TOTAL values for the same Date
mask_total = fuidx_vol['clienttype'].str.upper() == 'TOTAL'
total_long = fuidx_vol.loc[mask_total, 'fuidxlong'].values[0]
total_short = fuidx_vol.loc[mask_total, 'fuidxshort'].values[0]

# Calculate percentages
fuidx_vol['fuidxlong_pct'] = (fuidx_vol['fuidxlong'] / total_long * 100).round(3)
fuidx_vol['fuidxshort_pct'] = (fuidx_vol['fuidxshort'] / total_short * 100).round(3)

# --- Dynamically get total_val and totvolavg from fno ---
# Merge fuidx_vol with fno to bring in Index Futures values for the same Date
fno['product'] = fno['product'].str.strip()
idx_fut = fno[fno['product'] == 'Index Futures'][['Date','noofcons','Trdvalrscrs']]

# Join on Date
fuidx_vol = fuidx_vol.merge(idx_fut, on='Date', how='left')

# total_val = Trdvalrscrs (in crores)
#fuidx_vol['Trdvalrscrs'] = fno['Trdvalrscrs']

# totvolavg = Trdvalrscrs / noofcons (crores per contract), rounded to 3 decimals
fuidx_vol['conavg_lac'] = (fuidx_vol['Trdvalrscrs']*100 / fuidx_vol['noofcons']).round(3)

# Calculate Pbaselong_cr and Pbaseshort_cr using dynamic total_val
fuidx_vol['Pbaselong_cr'] = (fuidx_vol['fuidxlong_pct'] / 100 * fuidx_vol['Trdvalrscrs']).round(3)
fuidx_vol['Pbaseshort_cr'] = (fuidx_vol['fuidxshort_pct'] / 100 * fuidx_vol['Trdvalrscrs']).round(3)

# Calculate AvgbaseAmt_cr using dynamic totvolavg
fuidx_vol['long_AvgbaseAmt_cr'] = (fuidx_vol['fuidxlong'] * fuidx_vol['conavg_lac']/100).round(3)
fuidx_vol['short_AvgbaseAmt_cr'] = (fuidx_vol['fuidxshort'] * fuidx_vol['conavg_lac']/100).round(3)

fuidx_vol.head()
# Out:
# Loaded table: participant_oi, rows: 1015
# Loaded table: participant_vol, rows: 1015
# Loaded table: fustk, rows: 41956
# Loaded table: fii, rows: 2954
# Loaded table: fuidx, rows: 1182
# Loaded table: fnototal, rows: 985
# Loaded table: fnoidx_pct_oi, rows: 995
# Loaded table: fnoidx_pct_vol, rows: 995
# Loaded table: fnostk_pct_oi, rows: 995
# Loaded table: fnostk_pct_vol, rows: 995
#          Date clienttype  fuidxlong  fuidxshort  fuidxlong_pct  \
# 0  2026-02-17     Client      52634       50366         49.772
# 1  2026-02-17        DII        977        2832          0.924
# 2  2026-02-17        FII      15171       11291         14.346
# 3  2026-02-17        Pro      36968       41261         34.958
# 4  2026-02-17      TOTAL     105750      105750        100.000
#
#    fuidxshort_pct  noofcons  Trdvalrscrs  conavg_lac  Pbaselong_cr  \
# 0          47.627  105750.0     18098.41      17.114      9007.941
# 1           2.678  105750.0     18098.41      17.114       167.229
# ...

# %%
fno.head()
# Out:
#          Date        product   noofcons  Trdvalrscrs    AvgVal_lac
# 0  2026-02-17  Index Futures     105750     18098.41  17114.335697
# 1  2026-02-17  Stock Futures    1536843    103106.47   6708.978731
# 2  2026-02-17  Index Options  422218660  70617765.00  16725.401241
# 3  2026-02-17  Stock Options    9519473    664653.04   6982.036085
# 4  2026-02-17      F&O Total  433380726  71403622.92  16475.957198

# %%
fno.head()
# Out:
#          Date        product   noofcons  Trdvalrscrs    AvgVal_lac
# 0  2026-02-17  Index Futures     105750     18098.41  17114.335697
# 1  2026-02-17  Stock Futures    1536843    103106.47   6708.978731
# 2  2026-02-17  Index Options  422218660  70617765.00  16725.401241
# 3  2026-02-17  Stock Options    9519473    664653.04   6982.036085
# 4  2026-02-17      F&O Total  433380726  71403622.92  16475.957198
