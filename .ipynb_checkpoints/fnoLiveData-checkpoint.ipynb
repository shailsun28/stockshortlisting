# %%
import httpx
import requests
import brotli
import json
import time
import pandas as pd  # Ensure Pandas is installed
import sqlite3
import os
from datetime import datetime, date
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
BASE_DIR = "/home/shail/stockshortlisting"
BASE_DIR_db = "/home/shail/db"

# %% [markdown]
# ## Growth DB

# %%
growdb = os.path.join(BASE_DIR_db, "growth_nse_db.db")
gr_conn = sqlite3.connect(growdb)
query_gr = f"SELECT * FROM cm_growth "
grow_df = pd.read_sql_query(query_gr, gr_conn)
grow_df.head()
# Out:
#          date  Trdstocks  NoTrades       Tval      Tvol     Avg
# 0  2026-01-05       3262  33595563  104602.45  53878.58  194.14
# 1  2026-01-02       3252  31153061  102438.51  57032.98  179.61
# 2  2026-01-01       3227  24411272   80232.39  60232.28  133.20
# 3  2025-12-31       3256  30669987  100695.76  76607.12  131.44
# 4  2025-12-30       3247  38942416  141795.39  56318.72  251.77

# %%
stock = 'BANKNIFTY'

# %%
spurdb = os.path.join(BASE_DIR_db, "fuopspur.db")
conn = sqlite3.connect(spurdb)
query_spur = f"SELECT * FROM spur WHERE symbol = '{stock}'ORDER BY Date DESC , Time DESC"
df = pd.read_sql_query(query_spur, conn)

# %%
df.head()
# Out:
#       symbol  latestOI   prevOI  changeInOI  avgInOI    volume      futValue  \
# 0  BANKNIFTY   1598056  1419042      179014    12.62  16777169  826091.17273
# 1  BANKNIFTY   1598102  1419042      179060    12.62  16685139  822243.75307
# 2  BANKNIFTY   1615396  1419042      196354    13.84  16548855  812964.27450
# 3  BANKNIFTY   1615517  1419042      196475    13.85  16453340  809293.87176
# 4  BANKNIFTY   1631176  1419042      212134    14.95  16341636  805180.48679
#
#          optValue         total     premValue  underlyingValue   Time  \
# 0  30758556626462  1.750570e+06  924479.27462            61275  15:32
# 1  30590673323532  1.743315e+06  921071.51532            61297  15:30
# 2  30342298044728  1.729633e+06  916668.39728            61280  15:28
# 3  30167442669874  1.722091e+06  912796.89874            61280  15:26
# 4  29962712939840  1.713496e+06  908315.66840            61269  15:24
#
#          Date
# 0  2026-02-23
# 1  2026-02-23
# 2  2026-02-23
# 3  2026-02-23
# 4  2026-02-23

# %%
idxfudb = os.path.join(BASE_DIR_db, "idxfutures.db")
idx_conn = sqlite3.connect(idxfudb)
query_idx = f"SELECT * FROM futuresIndex WHERE Stock = '{stock}'ORDER BY Date DESC , Time DESC"
idxdf = pd.read_sql_query(query_idx, idx_conn)
idxdf.head()
# Out:
#        Stock        Date      Time   Ltp_fu PrChg_fu  %Prchg_fu Tsell_fu  \
# 0  BANKNIFTY  2026-02-23     15:53    61219     39.8       0.07    32250
# 1  BANKNIFTY  2026-02-23  15:32:03    61219     39.8       0.07    32250
# 2  BANKNIFTY  2026-02-23  15:30:03    61208     28.8       0.05    29550
# 3  BANKNIFTY  2026-02-23  15:28:03  61225.2       46       0.08    36060
# 4  BANKNIFTY  2026-02-23  15:26:03    61237     57.8       0.09    41220
#
#   Tbuy_fu Tvol_fu      Tvalue_fu   fuOI
# 0   28170   22715    41718764241  28727
# 1   28170   22715    41718764241  28727
# 2   23220   22642  41584725133.8  28727
# 3   33840   22495  41314728658.5  28727
# 4   31800   22380    41103510840  28777

# %% [markdown]
# ## Futures and Options Live Date Processing

# %%
starttime = datetime.now()
print("\2\n"+ " ******************  Script run started  at ...   ", starttime)

dbpath = os.path.join(BASE_DIR_db, "fuopspur.db")
conn = sqlite3.connect(dbpath)
current_date = starttime.strftime('%Y-%m-%d')
#n50fu_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_fut"
#n50op_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_opt"
#nbfu_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nifty_bank_fut"
#nbop_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nifty_bank_opt"

api_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_fut"

# Headers to mimic a real browser request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36",
    "Accept": "application/json, text/plain, */*",
    "Referer": "https://www.nseindia.com/market-data/oi-spurts",
    "Connection": "keep-alive",
    "Accept-Encoding": "gzip, deflate, br"
	}

# Main NSE site to retrieve cookies
main_url = "https://www.nseindia.com"

# Start session with httpx
with httpx.Client() as client:
    try:
	    response = client.get(main_url, headers=headers)
	    response.raise_for_status()
	    cookies = dict(client.cookies)  # Extract cookies
	    time.sleep(3)  # Wait briefly before the next request	
	    response2 = client.get(api_url, headers=headers, cookies=cookies)
	    response2.raise_for_status()
	    data = json.loads(response2.text)
	    df = pd.json_normalize(data['data'])
	    current_time = starttime.strftime('%H:%M')
	    df['Time'] = current_time
	    df['Date'] = current_date
	    #print(df.shape)
    except httpx.HTTPStatusError as e:
        print(f"Error fetching data: {e}")
#df.to_sql('spur', conn, if_exists='append', index=False)
conn.close()
#df.to_sql('spur', conn, if_exists='append', index=False)
#bank = df[nfcolumns]
endtime = datetime.now()
elapsed = endtime - starttime

# total seconds as float
total_seconds = elapsed.total_seconds()
# minutes and seconds
minutes = int(total_seconds // 60)
seconds = int(total_seconds % 60)
milliseconds = int((total_seconds - int(total_seconds)) * 1000)
print(f"The time taken to complete the task is {minutes}:{seconds:02d}.{milliseconds:03d}")
# Out:
#  ******************  Script run started  at ...    2026-02-23 16:44:10.223918
# The time taken to complete the task is 0:03.487

# %%
df.head()
# Out:
#   underlying                   identifier instrumentType     instrument  \
# 0      NIFTY  FUTIDXNIFTY24-02-2026XX0.00         FUTIDX  Index Futures
# 1      NIFTY  FUTIDXNIFTY30-03-2026XX0.00         FUTIDX  Index Futures
# 2      NIFTY  FUTIDXNIFTY28-04-2026XX0.00         FUTIDX  Index Futures
#
#             contract   expiryDate optionType  strikePrice  lastPrice  change  \
# 0  NIFTY 24-Feb-2026  24-Feb-2026          -            0    25700.3   115.6
# 1  NIFTY 30-Mar-2026  30-Mar-2026          -            0    25855.0   112.4
# 2  NIFTY 28-Apr-2026  28-Apr-2026          -            0    26005.1   106.0
#
#    ...  closePrice   volume  totalTurnover         value  premiumTurnOver  \
# 0  ...           0  8002605   2.054915e+11  2.054915e+11     2.054915e+11
# 1  ...           0  6173180   1.594704e+11  1.594704e+11     1.594704e+11
# 2  ...           0   293085   7.622232e+09  7.622232e+09     7.622232e+09
#
#    underlyingValue  openInterest  noOfTrades   Time        Date
# 0            25713        209503      123117  16:44  2026-02-23
# 1            25713        151834       94972  16:44  2026-02-23
# 2            25713         10101        4509  16:44  2026-02-23
#
# [3 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['underlying', 'identifier', 'instrumentType', 'instrument', 'contract',
#        'expiryDate', 'optionType', 'strikePrice', 'lastPrice', 'change',
#        'pChange', 'openPrice', 'highPrice', 'lowPrice', 'closePrice', 'volume',
#        'totalTurnover', 'value', 'premiumTurnOver', 'underlyingValue',
#        'openInterest', 'noOfTrades', 'Time', 'Date'],
#       dtype='object')

# %%
reqcol = ['underlying', 'instrumentType', 'contract',
       'lastPrice', 'change',
       'pChange','highPrice', 'lowPrice',  'volume',
       'totalTurnover', 'value', 'premiumTurnOver', 'underlyingValue',
       'openInterest', 'noOfTrades', 'Time', 'Date']
df = df[reqcol]

# %%
df.head()
# Out:
#   underlying instrumentType           contract  lastPrice  change  pChange  \
# 0      NIFTY         FUTIDX  NIFTY 24-Feb-2026    25700.3   115.6     0.45
# 1      NIFTY         FUTIDX  NIFTY 30-Mar-2026    25855.0   112.4     0.44
# 2      NIFTY         FUTIDX  NIFTY 28-Apr-2026    26005.1   106.0     0.41
#
#    highPrice  lowPrice   volume  totalTurnover         value  premiumTurnOver  \
# 0    25779.9   25593.3  8002605   2.054915e+11  2.054915e+11     2.054915e+11
# 1    25934.6   25758.5  6173180   1.594704e+11  1.594704e+11     1.594704e+11
# 2    26078.0   25925.0   293085   7.622232e+09  7.622232e+09     7.622232e+09
#
#    underlyingValue  openInterest  noOfTrades   Time        Date
# 0            25713        209503      123117  16:00  2026-02-23
# 1            25713        151834       94972  16:00  2026-02-23
# 2            25713         10101        4509  16:00  2026-02-23

# %% [markdown]
# ## Using request instead of client.

# %%
starttime = datetime.now()
print("\2\n"+ " ******************  Script run started  at ...   ", starttime)
current_date = starttime.strftime('%Y-%m-%d')
main_url = 'https://www.nseindia.com'
#fno_url = f'https://www.nseindia.com/api/NextApi/apiClient/GetQuoteApi?functionName=getSymbolDerivativesData&symbol={encoded_stock}'
fno_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_fut"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/91.0.4472.124 Safari/537.36',
    'Referer': main_url,
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5'
}
session = requests.Session()
retry = Retry(
    total=2,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["GET"]
)
adapter = HTTPAdapter(max_retries=retry)
session.mount("https://", adapter)
session.mount("http://", adapter)
try:
    session.get(main_url, headers=headers)
    time.sleep(1)
    response2 = session.get(fno_url, headers=headers)
    response2.raise_for_status()
    fno = response2.json()
    df = pd.json_normalize(fno['data'])
    current_time = starttime.strftime('%H:%M')
    # These lines below were likely causing the TabError
    df['Time'] = current_time
    df['Date'] = current_date

except requests.exceptions.RequestException as e:
    print(f"An error occurred for : {e}")

#df.to_sql('spur', conn, if_exists='append', index=False)
#bank = df[nfcolumns]
endtime = datetime.now()
elapsed = endtime - starttime

# total seconds as float
total_seconds = elapsed.total_seconds()
# minutes and seconds
minutes = int(total_seconds // 60)
seconds = int(total_seconds % 60)
milliseconds = int((total_seconds - int(total_seconds)) * 1000)
print(f"The time taken to complete the task is {minutes}:{seconds:02d}.{milliseconds:03d}")
# Out:
#  ******************  Script run started  at ...    2026-02-23 16:20:09.959504
# The time taken to complete the task is 0:01.229

# %%
reqcol = ['underlying', 'instrumentType', 'contract',
       'lastPrice', 'change',
       'pChange','highPrice', 'lowPrice',  'volume',
       'totalTurnover', 'value', 'premiumTurnOver', 'underlyingValue',
       'openInterest', 'noOfTrades', 'Time', 'Date']
df = df[reqcol]
df.head()
# Out:
#   underlying instrumentType           contract  lastPrice  change  pChange  \
# 0      NIFTY         FUTIDX  NIFTY 24-Feb-2026    25700.3   115.6     0.45
# 1      NIFTY         FUTIDX  NIFTY 30-Mar-2026    25855.0   112.4     0.44
# 2      NIFTY         FUTIDX  NIFTY 28-Apr-2026    26005.1   106.0     0.41
#
#    highPrice  lowPrice   volume  totalTurnover         value  premiumTurnOver  \
# 0    25779.9   25593.3  8002605   2.054915e+11  2.054915e+11     2.054915e+11
# 1    25934.6   25758.5  6173180   1.594704e+11  1.594704e+11     1.594704e+11
# 2    26078.0   25925.0   293085   7.622232e+09  7.622232e+09     7.622232e+09
#
#    underlyingValue  openInterest  noOfTrades   Time        Date
# 0            25713        209503      123117  16:19  2026-02-23
# 1            25713        151834       94972  16:19  2026-02-23
# 2            25713         10101        4509  16:19  2026-02-23

# %% [markdown]
# ## Bank Nifty Futures Live data.

# %%
starttime = datetime.now()
print("\2\n"+ " ******************  Script run started  at ...   ", starttime)
current_date = starttime.strftime('%Y-%m-%d')
main_url = 'https://www.nseindia.com'
#fno_url = f'https://www.nseindia.com/api/NextApi/apiClient/GetQuoteApi?functionName=getSymbolDerivativesData&symbol={encoded_stock}'
#fno_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_fut"
nbfu_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nifty_bank_fut"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/91.0.4472.124 Safari/537.36',
    'Referer': main_url,
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5'
}
session = requests.Session()
retry = Retry(
    total=2,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["GET"]
)
adapter = HTTPAdapter(max_retries=retry)
session.mount("https://", adapter)
session.mount("http://", adapter)
try:
    session.get(main_url, headers=headers)
    time.sleep(1)
    response2 = session.get(nbfu_url, headers=headers)
    response2.raise_for_status()
    fno = response2.json()
    df = pd.json_normalize(fno['data'])
    current_time = starttime.strftime('%H:%M')
    # These lines below were likely causing the TabError
    df['Time'] = current_time
    df['Date'] = current_date


except requests.exceptions.RequestException as e:
    print(f"An error occurred for : {e}")

#df.to_sql('spur', conn, if_exists='append', index=False)
#bank = df[nfcolumns]
reqcol = ['underlying', 'instrumentType', 'contract',
       'lastPrice', 'change',
       'pChange','highPrice', 'lowPrice',  'volume',
       'totalTurnover', 'value', 'premiumTurnOver', 'underlyingValue',
       'openInterest', 'noOfTrades', 'Time', 'Date']
df = df[reqcol]
endtime = datetime.now()
elapsed = endtime - starttime

# total seconds as float
total_seconds = elapsed.total_seconds()
# minutes and seconds
minutes = int(total_seconds // 60)
seconds = int(total_seconds % 60)
milliseconds = int((total_seconds - int(total_seconds)) * 1000)
print(f"The time taken to complete the task is {minutes}:{seconds:02d}.{milliseconds:03d}")
# Out:
#  ******************  Script run started  at ...    2026-02-23 16:39:02.336545
# The time taken to complete the task is 0:01.351

# %%
df.head()
# Out:
#   underlying instrumentType               contract  lastPrice  change  \
# 0  BANKNIFTY         FUTIDX  BANKNIFTY 24-Feb-2026    61219.0    39.8
# 1  BANKNIFTY         FUTIDX  BANKNIFTY 30-Mar-2026    61603.4    57.6
# 2  BANKNIFTY         FUTIDX  BANKNIFTY 28-Apr-2026    61940.0    73.2
#
#    pChange  highPrice  lowPrice  volume  totalTurnover         value  \
# 0     0.07    61500.0   61020.2  681450   4.171876e+10  4.171876e+10
# 1     0.09    61850.0   61416.0  635610   3.915076e+10  3.915076e+10
# 2     0.12    62175.8   61764.0   28080   1.739593e+09  1.739593e+09
#
#    premiumTurnOver  underlyingValue  openInterest  noOfTrades   Time  \
# 0     4.171876e+10         61264.25         28727       22715  16:39
# 1     3.915076e+10         61264.25         37365       21187  16:39
# 2     1.739593e+09         61264.25          3077         936  16:39
#
#          Date
# 0  2026-02-23
# 1  2026-02-23
# 2  2026-02-23

# %% [markdown]
# ## Bank Nifty Options Live Data.

# %%
starttime = datetime.now()
print("\2\n"+ " ******************  Script run started  at ...   ", starttime)
current_date = starttime.strftime('%Y-%m-%d')
main_url = 'https://www.nseindia.com'
#n50fu_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_fut"
#n50op_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_opt"
#nbfu_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nifty_bank_fut"
nbop_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nifty_bank_opt"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/91.0.4472.124 Safari/537.36',
    'Referer': main_url,
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5'
}
session = requests.Session()
retry = Retry(
    total=2,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["GET"]
)
adapter = HTTPAdapter(max_retries=retry)
session.mount("https://", adapter)
session.mount("http://", adapter)
try:
    session.get(main_url, headers=headers)
    time.sleep(1)
    response2 = session.get(nbop_url, headers=headers)
    response2.raise_for_status()
    fno = response2.json()
    df = pd.json_normalize(fno['data'])
    current_time = starttime.strftime('%H:%M')
    # These lines below were likely causing the TabError
    df['Time'] = current_time
    df['Date'] = current_date


except requests.exceptions.RequestException as e:
    print(f"An error occurred for : {e}")

#df.to_sql('spur', conn, if_exists='append', index=False)
#bank = df[nfcolumns]
opcol = ['underlying', 'instrumentType', 'contract',
       'optionType', 'strikePrice', 'lastPrice', 'change',
       'pChange','highPrice', 'lowPrice', 'volume',
       'totalTurnover', 'value', 'premiumTurnOver', 'underlyingValue',
       'openInterest', 'noOfTrades', 'Time', 'Date']
df = df[opcol]
endtime = datetime.now()
elapsed = endtime - starttime

# total seconds as float
total_seconds = elapsed.total_seconds()
# minutes and seconds
minutes = int(total_seconds // 60)
seconds = int(total_seconds % 60)
milliseconds = int((total_seconds - int(total_seconds)) * 1000)
print(f"The time taken to complete the task is {minutes}:{seconds:02d}.{milliseconds:03d}")
# Out:
#  ******************  Script run started  at ...    2026-02-23 16:29:54.820149
# The time taken to complete the task is 0:01.250

# %%
df.head()
# Out:
#   underlying instrumentType               contract optionType  strikePrice  \
# 0  BANKNIFTY         OPTIDX  BANKNIFTY 24-Feb-2026        Put        61000
# 1  BANKNIFTY         OPTIDX  BANKNIFTY 24-Feb-2026       Call        61300
# 2  BANKNIFTY         OPTIDX  BANKNIFTY 24-Feb-2026       Call        61200
# 3  BANKNIFTY         OPTIDX  BANKNIFTY 24-Feb-2026       Call        61500
# 4  BANKNIFTY         OPTIDX  BANKNIFTY 24-Feb-2026        Put        61200
#
#    lastPrice  change  pChange  highPrice  lowPrice    volume  totalTurnover  \
# 0     134.95 -102.85   -43.25     260.00    105.90  37859100   6.980839e+09
# 1     175.35  -79.15   -31.10     379.90    128.95  27244950   6.086794e+09
# 2     225.00  -75.85   -25.21     447.45    164.40  26960400   7.018331e+09
# 3     103.00  -67.55   -39.61     268.15     78.15  26895870   3.882688e+09
# 4     213.20 -106.35   -33.28     367.10    152.00  26153250   6.898443e+09
#
#           value  premiumTurnOver  underlyingValue  openInterest  noOfTrades  \
# 0  6.980839e+09     2.316386e+12         61264.25       42251.0     1261970
# 1  6.086794e+09     1.676202e+12         61264.25       26395.0      908165
# 2  7.018331e+09     1.656995e+12         61264.25       22479.0      898680
# 3  3.882688e+09     1.657979e+12         61264.25       34797.0      896529
# 4  6.898443e+09     1.607477e+12         61264.25       15870.0      871775
#
#     Time        Date
# 0  16:29  2026-02-23
# 1  16:29  2026-02-23
# 2  16:29  2026-02-23
# 3  16:29  2026-02-23
# 4  16:29  2026-02-23

# %%
df.columns
# Out:
# Index(['underlying', 'identifier', 'instrumentType', 'instrument', 'contract',
#        'expiryDate', 'optionType', 'strikePrice', 'lastPrice', 'change',
#        'pChange', 'openPrice', 'highPrice', 'lowPrice', 'closePrice', 'volume',
#        'totalTurnover', 'value', 'premiumTurnOver', 'underlyingValue',
#        'openInterest', 'noOfTrades', 'Time', 'Date'],
#       dtype='object')

# %%
opcol = ['underlying', 'instrumentType' 'contract',
       'optionType', 'strikePrice', 'lastPrice', 'change',
       'pChange','highPrice', 'lowPrice', 'volume',
       'totalTurnover', 'value', 'premiumTurnOver', 'underlyingValue',
       'openInterest', 'noOfTrades', 'Time', 'Date']

# %%
starttime = datetime.now()
print("\2\n"+ " ******************  Script run started  at ...   ", starttime)
current_date = starttime.strftime('%Y-%m-%d')
main_url = 'https://www.nseindia.com'
#n50fu_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_fut"
#n50op_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_opt"
#nbfu_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nifty_bank_fut"
nbop_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nifty_bank_opt"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/91.0.4472.124 Safari/537.36',
    'Referer': main_url,
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5'
}
session = requests.Session()
retry = Retry(
    total=2,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["GET"]
)
adapter = HTTPAdapter(max_retries=retry)
session.mount("https://", adapter)
session.mount("http://", adapter)
try:
    session.get(main_url, headers=headers)
    time.sleep(1)
    response2 = session.get(nbop_url, headers=headers)
    response2.raise_for_status()
    fno = response2.json()
    df = pd.json_normalize(fno['data'])
    df['Date'], df['Time'] = fno['timestamp'].split()

except requests.exceptions.RequestException as e:
    print(f"An error occurred for : {e}")

#df.to_sql('spur', conn, if_exists='append', index=False)
#bank = df[nfcolumns]
opcol = ['underlying', 'instrumentType', 'contract',
       'optionType', 'strikePrice', 'lastPrice', 'change',
       'pChange','highPrice', 'lowPrice', 'volume',
       'totalTurnover', 'value', 'premiumTurnOver', 'underlyingValue',
       'openInterest', 'noOfTrades', 'Time', 'Date']
df = df[opcol]
endtime = datetime.now()
elapsed = endtime - starttime

# total seconds as float
total_seconds = elapsed.total_seconds()
# minutes and seconds
minutes = int(total_seconds // 60)
seconds = int(total_seconds % 60)
milliseconds = int((total_seconds - int(total_seconds)) * 1000)
print(f"The time taken to complete the task is {minutes}:{seconds:02d}.{milliseconds:03d}")
# Out:
#  ******************  Script run started  at ...    2026-02-23 16:40:51.887317
# The time taken to complete the task is 0:01.390

# %%
df.head()
# Out:
#   underlying instrumentType               contract optionType  strikePrice  \
# 0  BANKNIFTY         OPTIDX  BANKNIFTY 24-Feb-2026        Put        61000
# 1  BANKNIFTY         OPTIDX  BANKNIFTY 24-Feb-2026       Call        61300
# 2  BANKNIFTY         OPTIDX  BANKNIFTY 24-Feb-2026       Call        61200
# 3  BANKNIFTY         OPTIDX  BANKNIFTY 24-Feb-2026       Call        61500
# 4  BANKNIFTY         OPTIDX  BANKNIFTY 24-Feb-2026        Put        61200
#
#    lastPrice  change  pChange  highPrice  lowPrice    volume  totalTurnover  \
# 0     134.95 -102.85   -43.25     260.00    105.90  37859100   6.980839e+09
# 1     175.35  -79.15   -31.10     379.90    128.95  27244950   6.086794e+09
# 2     225.00  -75.85   -25.21     447.45    164.40  26960400   7.018331e+09
# 3     103.00  -67.55   -39.61     268.15     78.15  26895870   3.882688e+09
# 4     213.20 -106.35   -33.28     367.10    152.00  26153250   6.898443e+09
#
#           value  premiumTurnOver  underlyingValue  openInterest  noOfTrades  \
# 0  6.980839e+09     2.316386e+12         61264.25       42251.0     1261970
# 1  6.086794e+09     1.676202e+12         61264.25       26395.0      908165
# 2  7.018331e+09     1.656995e+12         61264.25       22479.0      898680
# 3  3.882688e+09     1.657979e+12         61264.25       34797.0      896529
# 4  6.898443e+09     1.607477e+12         61264.25       15870.0      871775
#
#        Time         Date
# 0  15:30:00  23-Feb-2026
# 1  15:30:00  23-Feb-2026
# 2  15:30:00  23-Feb-2026
# 3  15:30:00  23-Feb-2026
# 4  15:30:00  23-Feb-2026

# %%
df.shape
# Out:
# (894, 19)

# %% [markdown]
# ## OI Spurts Underlying and Contracts
# ### https://www.nseindia.com/api/live-analysis-oi-spurts-underlyings
# ### https://www.nseindia.com/api/live-analysis-oi-spurts-contracts

# %%
main_url = 'https://www.nseindia.com'
#n50fu_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_fut"
#n50op_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_opt"
#nbfu_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nifty_bank_fut"
#oispurts_url = "https://www.nseindia.com/api/live-analysis-oi-spurts-underlyings"
#oisprcon_url = "https://www.nseindia.com/api/live-analysis-oi-spurts-contracts"
oispurts_url = "https://www.nseindia.com/api/live-analysis-oi-spurts-underlyings"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/91.0.4472.124 Safari/537.36',
    'Referer': main_url,
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5'
}
session = requests.Session()
retry = Retry(
    total=2,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["GET"]
)
adapter = HTTPAdapter(max_retries=retry)
session.mount("https://", adapter)
session.mount("http://", adapter)
try:
    session.get(main_url, headers=headers)
    time.sleep(1)
    response2 = session.get(oispurts_url, headers=headers)
    response2.raise_for_status()
    fno = response2.json()
    df = pd.json_normalize(fno['data'])
    df['Date'], df['Time'] = fno['timestamp'].split()

except requests.exceptions.RequestException as e:
    print(f"An error occurred for : {e}")
df.head()
# Out:
#        symbol  latestOI  prevOI  changeInOI  avgInOI  volume      futValue  \
# 0  IDFCFIRSTB    111250   57575       53675    93.23  354934  537807.52116
# 1         UPL     65759   41688       24071    57.74  235078  367891.99245
# 2  BAJAJHLDNG     11068    7068        4000    56.59   73971   29086.35531
# 3  CUMMINSIND     43411   34066        9345    27.43  147545  190988.51098
# 4     ICICIGI     33194   26065        7129    27.35   23544   92990.18524
#
#        optValue         total    premValue  underlyingValue         Date  \
# 0  191346674608  596061.68424  58254.16308               70  23-Feb-2026
# 1  181150753677  395572.65222  27680.65977              645  23-Feb-2026
# 2   40280428453   31024.63984   1938.28453            11495  23-Feb-2026
# 3  126133003354  199686.14452   8697.63354             4880  23-Feb-2026
# 4    5727090066   93238.40591    248.22066             1949  23-Feb-2026
#
#        Time
# 0  15:31:39
# 1  15:31:39
# 2  15:31:39
# 3  15:31:39
# 4  15:31:39

# %% [markdown]
# ## Spurts Contracts.

# %%
main_url = 'https://www.nseindia.com'
#n50fu_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_fut"
#n50op_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_opt"
#nbfu_url = "https://www.nseindia.com/api/liveEquity-derivatives?index=nifty_bank_fut"
#oispurts_url = "https://www.nseindia.com/api/live-analysis-oi-spurts-underlyings"
#oisprcon_url = "https://www.nseindia.com/api/live-analysis-oi-spurts-contracts"
oisprcon_url = "https://www.nseindia.com/api/live-analysis-oi-spurts-contracts"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/91.0.4472.124 Safari/537.36',
    'Referer': main_url,
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5'
}
session = requests.Session()
retry = Retry(
    total=2,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["GET"]
)
adapter = HTTPAdapter(max_retries=retry)
session.mount("https://", adapter)
session.mount("http://", adapter)
try:
    session.get(main_url, headers=headers)
    time.sleep(1)
    response2 = session.get(oisprcon_url, headers=headers)
    response2.raise_for_status()
    fno = response2.json()
    df = pd.json_normalize(fno['data'])
    df['Date'], df['Time'] = fno['timestamp'].split()

except requests.exceptions.RequestException as e:
    print(f"An error occurred for : {e}")
df.head()
# Out:
#                                    Slide-in-OI-Slide  \
# 0  [{'type': 'SS', 'symbol': 'NIFTY', 'instrument...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#                                     Slide-in-OI-Rise  \
# 0                                                NaN
# 1  [{'type': 'SR', 'symbol': 'NIFTY', 'instrument...
# 2                                                NaN
# 3                                                NaN
#
#                                      Rise-in-OI-Rise  \
# 0                                                NaN
# 1                                                NaN
# 2  [{'type': 'RR', 'symbol': 'HDFCBANK', 'instrum...
# 3                                                NaN
#
#                                     Rise-in-OI-Slide         Date      Time
# 0                                                NaN  23-Feb-2026  15:31:39
# 1                                                NaN  23-Feb-2026  15:31:39
# 2                                                NaN  23-Feb-2026  15:31:39
# 3  [{'type': 'RS', 'symbol': 'NIFTY', 'instrument...  23-Feb-2026  15:31:39

# %%
dfdata = pd.json_normalize(fno['data'][0]['Slide-in-OI-Slide'])
dfdata.head()
# Out:
#   type symbol     instrument   expiryDate optionType  strikePrice   ltp  \
# 0   SS  NIFTY  Index Options  24-Feb-2026       Call        27000  1.00
# 1   SS  NIFTY  Index Options  24-Feb-2026        Put        24800  6.05
# 2   SS  NIFTY  Index Options  24-Feb-2026       Call        27300  0.95
# 3   SS  NIFTY  Index Options  24-Feb-2026       Call        27500  0.75
# 4   SS  NIFTY  Index Options  24-Feb-2026       Call        26550  1.55
#
#    prevClose  pChange  latestOI  prevOI  changeInOI   volume    turnover  \
# 0       1.50   -33.33    187616  243925      -56309  1041659   866.66028
# 1      17.05   -64.52     69651  116021      -46370   836820  3383.26326
# 2       1.15   -17.39     28335   56821      -28486   178458   126.43749
# 3       1.05   -28.57     57251   82720      -25469   210023   128.32405
# 4       2.70   -42.59     15972   34856      -18884   562644   760.69468
#
#    premTurnover  underlyingValue                    identifier instrumentType  \
# 0     866.66028          25713.0  OPTIDXNIFTY24-02-2026CE27000         OPTIDX
# 1    3383.26326          25713.0  OPTIDXNIFTY24-02-2026PE24800         OPTIDX
# 2     126.43749          25713.0  OPTIDXNIFTY24-02-2026CE27300         OPTIDX
# 3     128.32405          25713.0  OPTIDXNIFTY24-02-2026CE27500         OPTIDX
# 4     760.69468          25713.0  OPTIDXNIFTY24-02-2026CE26550         OPTIDX
#
#    pChangeInOI
# 0       -23.08
# 1       -39.97
# 2       -50.13
# 3       -30.79
# 4       -54.18

# %%
df2 = pd.json_normalize(fno['data'][1]['Slide-in-OI-Rise'])
df3 = pd.json_normalize(fno['data'][2]['Rise-in-OI-Rise'])
df4 = pd.json_normalize(fno['data'][3]['Rise-in-OI-Slide'])
df2.head()
# Out:
#   type      symbol     instrument   expiryDate optionType  strikePrice  \
# 0   SR       NIFTY  Index Options  24-Feb-2026       Call        25600
# 1   SR       NIFTY  Index Options  24-Feb-2026       Call        25500
# 2   SR       NIFTY  Index Options  24-Feb-2026       Call        25550
# 3   SR       NIFTY  Index Options  24-Feb-2026       Call        25400
# 4   SR  BAJAJ-AUTO  Stock Futures  24-Feb-2026          -            0
#
#       ltp  prevClose  pChange  latestOI  prevOI  changeInOI   volume  \
# 0   144.5     119.35    21.07     73481  118035      -44554  4232600
# 1   224.6     179.25    25.30     58088   82816      -24728  1279710
# 2   184.5     145.30    26.98     18066   35385      -17319   990952
# 3   317.0     255.00    24.31     15772   23678       -7906   213319
# 4  9885.5    9813.50     0.73      6846   12697       -5851    12223
#
#        turnover  premTurnover  underlyingValue                     identifier  \
# 0  392512.27730  392512.27730          25713.0   OPTIDXNIFTY24-02-2026CE25600
# 1  182158.40038  182158.40038          25713.0   OPTIDXNIFTY24-02-2026CE25500
# 2  114047.67472  114047.67472          25713.0   OPTIDXNIFTY24-02-2026CE25550
# 3   42092.21173   42092.21173          25713.0   OPTIDXNIFTY24-02-2026CE25400
# 4   90422.45379   90422.45379           9884.5  FUTSTKBAJAJ-AUTO24-02-2026XX0
#
#   instrumentType  pChangeInOI
# 0         OPTIDX       -37.75
# 1         OPTIDX       -29.86
# 2         OPTIDX       -48.94
# 3         OPTIDX       -33.39
# 4         FUTSTK       -46.08

# %%
df3.head()
# Out:
#   type    symbol     instrument   expiryDate optionType  strikePrice  \
# 0   RR  HDFCBANK  Stock Futures  30-Mar-2026          -            0
# 1   RR     NIFTY  Index Options  24-Feb-2026       Call        25750
# 2   RR     NIFTY  Index Futures  30-Mar-2026          -            0
# 3   RR     NIFTY  Index Options  24-Feb-2026       Call        25700
# 4   RR  RELIANCE  Stock Futures  30-Mar-2026          -            0
#
#         ltp  prevClose  pChange  latestOI  prevOI  changeInOI    volume  \
# 0    930.40     919.65     1.17    441057  345913       95144    118352
# 1     59.55      57.20     4.11    152974   72289       80685   7473606
# 2  25855.00   25742.60     0.44    151834   86332       65502     94972
# 3     81.65      74.85     9.08    197150  136461       60689  11807537
# 4   1433.00    1429.60     0.24    177655  127804       49851     58464
#
#        turnover  premTurnover  underlyingValue                    identifier  \
# 0  6.042183e+05  6.042183e+05            924.1   FUTSTKHDFCBANK30-03-2026XX0
# 1  3.419922e+05  3.419922e+05          25713.0  OPTIDXNIFTY24-02-2026CE25750
# 2  1.594704e+06  1.594704e+06          25713.0      FUTIDXNIFTY30-03-2026XX0
# 3  6.771563e+05  6.771563e+05          25713.0  OPTIDXNIFTY24-02-2026CE25700
# 4  4.186841e+05  4.186841e+05           1425.0   FUTSTKRELIANCE30-03-2026XX0
#
#   instrumentType  pChangeInOI
# 0         FUTSTK        27.51
# 1         OPTIDX       111.61
# 2         FUTIDX        75.87
# 3         OPTIDX        44.47
# 4         FUTSTK        39.01

# %%
df4.head()
# Out:
#   type symbol     instrument   expiryDate optionType  strikePrice    ltp  \
# 0   RS  NIFTY  Index Options  24-Feb-2026        Put        25700  82.00
# 1   RS  NIFTY  Index Options  24-Feb-2026        Put        25600  47.10
# 2   RS  NIFTY  Index Options  24-Feb-2026       Call        26000   9.00
# 3   RS  NIFTY  Index Options  24-Feb-2026        Put        25650  62.15
# 4   RS  NIFTY  Index Options  24-Feb-2026       Call        25800  41.65
#
#    prevClose  pChange  latestOI  prevOI  changeInOI   volume      turnover  \
# 0     181.30   -54.77    171117   49925      121192  9877558  662714.99889
# 1     128.80   -63.43    173084   98538       74546  9367333  402163.02402
# 2      16.00   -43.75    285253  217495       67758  4775022   43483.73784
# 3     149.75   -58.50     96826   36187       60639  8302078  458905.66352
# 4      43.30    -3.81    225726  165418       60308  8720038  290939.70785
#
#    premTurnover  underlyingValue                    identifier instrumentType  \
# 0  662714.99889          25713.0  OPTIDXNIFTY24-02-2026PE25700         OPTIDX
# 1  402163.02402          25713.0  OPTIDXNIFTY24-02-2026PE25600         OPTIDX
# 2   43483.73784          25713.0  OPTIDXNIFTY24-02-2026CE26000         OPTIDX
# 3  458905.66352          25713.0  OPTIDXNIFTY24-02-2026PE25650         OPTIDX
# 4  290939.70785          25713.0  OPTIDXNIFTY24-02-2026CE25800         OPTIDX
#
#    pChangeInOI
# 0       242.75
# 1        75.65
# 2        31.15
# 3       167.57
# 4        36.46

# %%
df4['instrumentType'].unique()
# Out:
# array(['OPTIDX', 'FUTSTK'], dtype=object)
