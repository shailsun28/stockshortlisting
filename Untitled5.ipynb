# %%
import os
import sqlite3
import pandas as pd
import streamlit as st
import altair as alt
import numpy as np
import time
import requests
from datetime import date
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

BASE_DIR_db = "/home/shail/db"
BASE_DIR = "/home/shail/stockshortlisting"

# %%
allcolumns = ['Stock', 'Date', 'Time', 'fetch_time', 'Tbuy_eq', 'Tsell_eq',
       'Tvalue_eq', 'Tvol_eq', 'High_eq', 'PrChg_eq', '%Prchg_eq', 'Ltp_eq',
       'Vwap_eq', 'Ltp_fu', 'PrChg_fu', '%Prchg_fu', 'Tsell_fu', 'Tbuy_fu',
       'Tvol_fu', 'Tvalue_fu', 'fuOI']

# --- Page config ---
st.set_page_config(layout="wide")

@st.cache_data
def buysell_fno_func(stock: str):
    """
    Process buy/sell FNO data for a single stock from niftybank.db/niftybank table.
    """
    db_path = os.path.join(BASE_DIR_db, "niftybank.db")
    todays_date = date.today()
    with sqlite3.connect(db_path) as tg_conn:
        tg_query = f"""
            SELECT * FROM niftybank
            WHERE Date = "{todays_date}" AND Stock = "{stock}"
            ORDER BY Time DESC
        """
        tgdf = pd.read_sql_query(tg_query, tg_conn)

    alldf = tgdf[tgdf['Stock'] == stock].sort_values(by=['Time'], ascending=False).reset_index(drop=True)
    if alldf.empty:
        return pd.DataFrame()

    numeric_cols = [
        'Tbuy_eq', 'Tsell_eq', 'Tvalue_eq', 'Tvol_eq',
        'High_eq', 'PrChg_eq', '%Prchg_eq', 'Ltp_eq', 'Vwap_eq', 'Ltp_fu',
        'PrChg_fu', '%Prchg_fu', 'Tsell_fu', 'Tbuy_fu', 'Tvol_fu',
        'Tvalue_fu', 'fuOI'
    ]
    alldf[numeric_cols] = alldf[numeric_cols].apply(pd.to_numeric, errors='coerce')
    alldf.fillna(0, inplace=True)

    # Transformations
    #alldf['Tvalue_eq'] = alldf['Tvalue_eq'] / 10000000
    alldf['ValChg%_eq'] = round((alldf['Tvalue_eq'] - alldf['Tvalue_eq'].shift(-1)) * 100 / alldf['Tvalue_eq'].shift(-1), 2)
    alldf['Valchg_eq'] = alldf['Tvalue_eq'] - alldf['Tvalue_eq'].shift(-1)
    alldf['VolChg%_eq'] = round((alldf['Tvol_eq'] - alldf['Tvol_eq'].shift(-1)) * 100 / alldf['Tvol_eq'].shift(-1), 2)
    alldf['Volchg_eq'] = round((alldf['Tvol_eq'] - alldf['Tvol_eq'].shift(-1)), 2)
    alldf['var%_eq'] = alldf['ValChg%_eq'] - alldf['VolChg%_eq']
    alldf['bsd%_eq'] = round(((alldf['Tbuy_eq'] - alldf['Tsell_eq']) * 100) / alldf['Tbuy_eq'], 2)

    alldf['ValChg%_fu'] = round((alldf['Tvalue_fu'] - alldf['Tvalue_fu'].shift(-1)) * 100 / alldf['Tvalue_fu'].shift(-1), 2)
    alldf['Valchg_fu'] = round((alldf['Tvalue_fu'] - alldf['Tvalue_fu'].shift(-1)), 3)
    alldf['VolChg%_fu'] = round((alldf['Tvol_fu'] - alldf['Tvol_fu'].shift(-1)) * 100 / alldf['Tvol_fu'].shift(-1), 2)
    alldf['Volchg_fu'] = round((alldf['Tvol_fu'] - alldf['Tvol_fu'].shift(-1)), 2)
    alldf['var%_fu'] = alldf['ValChg%_fu'] - alldf['VolChg%_fu']
    alldf['bsd%_fu'] = round(((alldf['Tbuy_fu'] - alldf['Tsell_fu']) * 100) / alldf['Tbuy_fu'], 2)

    alldf['tot%_eq'] = round(((alldf['Tbuy_eq'] - alldf['Tsell_eq']) * 100) / (alldf['Tbuy_eq'] + alldf['Tsell_eq']), 2)
    alldf['tot%_fu'] = round(((alldf['Tbuy_fu'] - alldf['Tsell_fu']) * 100) / (alldf['Tbuy_fu'] + alldf['Tsell_fu']), 2)
    alldf['avg_eq'] = round(alldf['Valchg_eq'] / (alldf['Volchg_eq']), 2)
    alldf['oichg_fu'] = round(alldf['fuOI'] - (alldf['fuOI'].shift(-1)), 2)
    alldf['avg_fu'] = round(alldf['Valchg_fu'] / (alldf['Volchg_fu']), 2)
    alldf['avgOI_fu'] = round(alldf['Valchg_fu'] / (alldf['oichg_fu']), 2)
    alldf['Valchg_fu'] = round(alldf['Valchg_fu'] / 10000000, 3)

    newcol = ['Stock', 'Date', 'Time', '%Prchg_eq','bsd%_eq', '%Prchg_fu', 'bsd%_fu',
              'tot%_eq', 'tot%_fu', 'Tbuy_eq', 'Tsell_eq', 'Tvalue_eq', 'Tvol_eq',
              'High_eq', 'PrChg_eq', 'Ltp_eq', 'Vwap_eq', 'Ltp_fu','PrChg_fu',
              'Tsell_fu', 'Tbuy_fu', 'Tvol_fu', 'Tvalue_fu','fuOI',
              'ValChg%_eq', 'Valchg_eq', 'VolChg%_eq', 'Volchg_eq', 'var%_eq',
              'ValChg%_fu', 'Valchg_fu', 'VolChg%_fu', 'Volchg_fu','var%_fu',
              'avg_eq', 'oichg_fu','avg_fu', 'avgOI_fu']
    alldf = alldf[newcol]
    return alldf

@st.cache_data
def shortlist_func(stock: str):
    """
    Process bhavcopy + 52-week data for a single stock.
    """
    db_path = os.path.join(BASE_DIR_db, "fullbhavcopy.db")
    conn = sqlite3.connect(db_path)

    # Load 52-week high/low data
    hl_52w_path = os.path.join(BASE_DIR, "52weekhl", "52_wk_High_low.csv")
    df1 = pd.read_csv(hl_52w_path)

    # Define all column renames in one dictionary
    rename_map = {
        'Adjusted_52_Week_High': '52WH',
        'Adjusted_52_Week_Low': '52WL',
        'TURNOVER_LACS': 'Val_CR',
        'TTL_TRD_QNTY': 'Vol',
        'HIGH_PRICE': 'HiPr',
        'LAST_PRICE': 'LTP',
        'AVG_PRICE': 'AvgPr',
        'SYMBOL': 'Stock',
        'DATE': 'Date',
        'LOW_PRICE': 'LoPr',
        'PREV_CLOSE': 'PvPr',
        'CLOSE_PRICE': 'ClPr'
    }

    df1.rename(columns=rename_map, inplace=True)

    query = f"SELECT * FROM nsestock_t WHERE SYMBOL = '{stock}' ORDER BY Date DESC LIMIT 360"
    hl_df = pd.read_sql_query(query, conn)

    hl_df['DELIV_QTY'] = hl_df['DELIV_QTY'].astype(float)
    hl_df.rename(columns=rename_map, inplace=True)

    hl_df['Val_CR'] = round(hl_df['Val_CR'] / 100, 3)
    hl_df = pd.merge(hl_df, df1[['Stock', '52WH', '52WL']], on='Stock', how='left')

    # Derived metrics
    hl_df['DlyAvg_10'] = round(hl_df['DELIV_QTY'].rolling(window=10, min_periods=10).mean().shift(-10), 1)
    hl_df['DlyRto_10'] = round(hl_df['DELIV_QTY'] / hl_df['DlyAvg_10'], 1)
    hl_df['Pr_chg'] = round(hl_df['ClPr'] - hl_df['PvPr'], 2)
    hl_df['Pr_chg_%'] = round((hl_df['ClPr'] - hl_df['PvPr']) * 100 / hl_df['PvPr'], 2)
    hl_df['LO52WNr%'] = round((hl_df['ClPr'] - hl_df['52WL']) * 100 / hl_df['52WL'], 2)
    hl_df['HI52WNr%'] = round((hl_df['52WH'] - hl_df['ClPr']) * 100 / hl_df['52WH'], 2)
    hl_df['DayHiNr%'] = round((hl_df['HiPr'] - hl_df['ClPr']) * 100 / hl_df['HiPr'], 2)
    hl_df['DayLoNr%'] = round((hl_df['ClPr'] - hl_df['LoPr']) * 100 / hl_df['LoPr'], 2)

    # Rolling averages
    periods = [1, 5, 10, 21, 50, 66, 96, 125, 190, 252]
    for period in periods:
        hl_df[f'SMA_{period}'] = round(hl_df['ClPr'].rolling(window=period, min_periods=period).mean().shift(-period), 1)
        hl_df[f'VolAvg_{period}'] = round(hl_df['Vol'].rolling(window=period, min_periods=period).mean().shift(-period), 1)
        hl_df[f'ValAvg_{period}'] = round(hl_df['Val_CR'].rolling(window=period, min_periods=period).mean().shift(-period), 1)
        hl_df.loc[:, f'ValChg%_Avg_{period}'] = round((hl_df['Val_CR'] - hl_df[f'ValAvg_{period}']) * 100 / hl_df[f'ValAvg_{period}'], 2)
        hl_df.loc[:, f'VolChg%_Avg_{period}'] = round((hl_df['Vol'] - hl_df[f'VolAvg_{period}']) * 100 / hl_df[f'VolAvg_{period}'], 2)

    hl_df['VolRto_10'] = round(hl_df['Vol'] / hl_df['VolAvg_10'], 1)
    hl_df.fillna(0, inplace=True)

    hl_df['Vol_lac'] = round(hl_df['Vol'] / 100000, 3)
    specific_map = { 'Pr_chg_%': 'prchg%', 'DlyRto_10': 'dly_RTO', 'VolRto_10': 'qty_rto' }
    
    # Reorder columns
     # --- Pattern-based rename: remove "Avg_" everywhere --- 
    hl_df.rename(columns=lambda c: c.replace("Avg_", ""), inplace=True)
    hl_df.rename(columns=specific_map, inplace=True)
    newcol = [
    'Stock', 'Date', 'dly_RTO', 'prchg%', 'qty_rto','LTP', 'HiPr', 
    'ValChg%_10', 'VolChg%_10', 'ValChg%_21', 'VolChg%_21',
    'ValChg%_50', 'VolChg%_50',
    'AvgPr', 'Val_CR','Vol_lac', 'LoPr', 'ClPr',
    'NO_OF_TRADES', 'DELIV_QTY', 'DELIV_PER',
    '52WH', '52WL', 'Dly10', 'Pr_chg', 'LO52WNr%', 'HI52WNr%',
    'DayHiNr%', 'DayLoNr%',
    'SMA_1', 'Vol1', 'Val1', 'ValChg%_1', 'VolChg%_1',
    'SMA_5', 'Vol5', 'Val5', 'ValChg%_5', 'VolChg%_5',
    'SMA_10', 'Vol10', 'Val10',
    'SMA_21', 'Vol21', 'Val21',
    'SMA_50', 'Vol50', 'Val50',
    'SMA_66', 'Vol66', 'Val66', 'ValChg%_66', 'VolChg%_66',
    'SMA_96', 'Vol96', 'Val96', 'ValChg%_96', 'VolChg%_96',
    'SMA_125', 'Vol125', 'Val125', 'ValChg%_125', 'VolChg%_125',
    'SMA_190', 'Vol190', 'Val190', 'ValChg%_190', 'VolChg%_190',
    'SMA_252', 'Vol252', 'Val252', 'ValChg%_252', 'VolChg%_252',
    'Vol'
    ]

    hl_df = hl_df[newcol]
 
    conn.close()
    return hl_df
def fetch_nse_data(stock: str):
    """
    Fetch NSE JSON data (quote + change history) for a single stock.
    Returns (qtyjson, chgjson) or (None, None) if request fails.
    """
    headers = {
        'User-Agent': 'Mozilla/5.0',
        'Referer': f'https://www.nseindia.com/get-quotes/equity?symbol={stock}',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
        'Accept-Language': 'en-US,en;q=0.5'
    }

    encoded_stock = stock.replace("&", "%26")
    main_url = "https://www.nseindia.com"
    qty_url = (
        f"https://www.nseindia.com/api/NextApi/apiClient/GetQuoteApi?"
        f"functionName=getSymbolData&marketType=N&series=EQ&symbol={encoded_stock}"
    )
    chg_url = (
        f"https://www.nseindia.com/api/NextApi/apiClient/GetQuoteApi?"
        f"functionName=getYearwiseData&symbol={encoded_stock}EQN"
    )

    session = requests.Session()
    retry = Retry(
        total=2,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=["GET"]
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount("https://", adapter)
    session.mount("http://", adapter)

    try:
        # Warm up session
        session.get(main_url, headers=headers)
        time.sleep(1)  # polite delay
        qty_resp = session.get(qty_url, headers=headers)
        qty_resp.raise_for_status()
        chg_resp = session.get(chg_url, headers=headers)
        chg_resp.raise_for_status()
        return qty_resp.json(), chg_resp.json()
    except requests.exceptions.RequestException as e:
        st.error(f"Error fetching NSE data for {stock}: {e}")
        return None, None

def parse_time(df, fmt):
    if 'Time' in df.columns and 'Date' in df.columns:
        df['DateTime'] = pd.to_datetime(
            df['Date'].astype(str) + ' ' + df['Time'].astype(str),
            format=f"%Y-%m-%d {fmt}", errors="coerce"
        )
        #df.sort_values(by='DateTime', inplace=True)
        df.sort_values(by='DateTime', ascending=False, inplace=True)
        df.reset_index(drop=True, inplace=True)
    return df

# --- Sidebar selectors ---
st.sidebar.header("Filter Options")

with sqlite3.connect(os.path.join(BASE_DIR_db, "niftybank.db")) as conn:
    fno_df = pd.read_sql_query("SELECT * FROM niftybank ORDER BY Date DESC", conn)

fno_stocks = fno_df['Stock'].unique() if not fno_df.empty else []
selected_fno_stock = st.sidebar.selectbox("Select an FNO Stock:", fno_stocks, key="fno_selector")
manual_stock = st.sidebar.text_input("Enter any Stock Symbol:", "").strip()

# NEW: column selector for Tab 3
available_cols = fno_df.columns.tolist()
#selected_column = st.sidebar.selectbox("Select column for All Stocks Graph:", available_cols)

tab1, tab2, tab3 = st.tabs(["FNO DlyRatio", "Fu & Eq BuySellData", "All Stocks Graph"])


if selected_fno_stock or manual_stock:
    stock_to_analyze = manual_stock if manual_stock else selected_fno_stock
    buysell_df_single = buysell_fno_func(stock_to_analyze)
    shortlisted_df_single = shortlist_func(stock_to_analyze)
    qtyjson, chgjson = fetch_nse_data(stock_to_analyze)

    # --- Tab 1 ---
    with tab1:

        #st.subheader(f"Fu & Eq BuySell Order Graphs for {stock_to_analyze}")    
        st.subheader(f"Fu & Eq BuySell Order Graphs for {stock_to_analyze}")
        if not buysell_df_single.empty:
            filtered_df = buysell_df_single.copy()
            #filtered_df['Time'] = pd.to_datetime(filtered_df['Time'], format="%H:%M:%S", errors="coerce")
            filtered_df['Time'] = pd.to_datetime(filtered_df['Time'], format="%H:%M", errors="coerce")
            filtered_df['Volchg_eq'] = round(filtered_df['Volchg_eq'] / 1000, 2)
            plot_df = filtered_df.reset_index(drop=True)

            chart_specs = [
                ("%Prchg_eq", "blue", "%Prchg_eq"),
                ("Valchg_eq", "blue", "Valchg_eq(cr)"),
                ("Volchg_eq", "green", "Volchg_eq(K)"),
                ("PrChg_eq", "orange", "PriceChg_eq"),
                ("%Prchg_fu", "orange", "%Prchg_fu"),
                ("bsd%_eq", "blue", "BuySellDiff_eq"),
                ("bsd%_fu", "orange", "BuySellDiff_fu"),
                ("tot%_eq", "blue", "TotBuySell_eq"),
                ("tot%_fu", "orange", "TotBuySell_fu"),
            ]
            for col, color, title in chart_specs:
                if col in plot_df.columns:
                    chart = (
                        alt.Chart(plot_df)
                        .mark_line(point=True)
                        .encode(x="Time:T", y=f"{col}:Q", color=alt.value(color))
                        .properties(width=1000, height=200, title=f"{title} for {stock_to_analyze}")
                    )
                    st.altair_chart(chart, use_container_width=True)
        else:
            st.warning(f"No BuySell data found for {stock_to_analyze}")
        st.subheader(f"Price Info for {stock_to_analyze}")    
        # Fetch NSE API JSON for the selected FNO stock
        qtyjson, chgjson = fetch_nse_data(stock_to_analyze)    

        # Derived metrics
        DayLoNrP, DayHiNrP = None, None
        if qtyjson:
            meta = qtyjson['equityResponse'][0]['metaData']
            ltp = qtyjson['equityResponse'][0]['tradeInfo']['lastPrice']
            day_low = meta['dayLow']
            day_high = meta['dayHigh']
            DayLoNrP = np.round((ltp - day_low) * 100 / ltp, 2)
            DayHiNrP = np.round((day_high - ltp) * 100 / ltp, 2)    

        # Display metrics in rows of 5
        if qtyjson and chgjson:
            metrics = [
                ("Change%", qtyjson['equityResponse'][0]['metaData']['pChange']),
                ("DayHiNr%", DayHiNrP),
                ("DayHigh", qtyjson['equityResponse'][0]['metaData']['dayHigh']),
                ("WeekChg%", chgjson[0]['one_week_chng_per']),
                ("MonthChg%", chgjson[0]['one_month_chng_per']),
                ("Ltp", qtyjson['equityResponse'][0]['tradeInfo']['lastPrice']),
                ("DayLoNrP%", DayLoNrP),
                ("DayLow", qtyjson['equityResponse'][0]['metaData']['dayLow']),
                ("PrChg", qtyjson['equityResponse'][0]['metaData']['change']),
                ("3MonChg%", chgjson[0]['three_month_chng_per']),
            ]
            for i in range(0, len(metrics), 5):
                cols = st.columns([0.9] * 5)
                for j, (label, value) in enumerate(metrics[i:i+5]):
                    cols[j].metric(label, value, border=True)    

        st.subheader(f"Delivery Ratio History for {stock_to_analyze}")
        shortlisted_df_single
    # ---
    with tab2:
        #st.subheader(f"Buy Sell Trade data for {selected_fno_stock}")
        st.subheader(f"Buy Sell Trade data for {stock_to_analyze}")
        st.dataframe(buysell_df_single)
    # --- Tab 3 ---
    with tab3:
        st.subheader("All Stocks Graphs")

        # Define allowed chart columns
        chart_specs = [
            ("Valchg_eq", "blue", "Valchg_eq(cr)"),
            ("Volchg_eq", "green", "Volchg_eq(K)"),
            ("%Prchg_fu", "orange", "%Prchg_fu"),
            ("%Prchg_eq", "blue", "%Prchg_eq"),
            ("PrChg_eq", "orange", "PriceChg_eq"),
            ("bsd%_eq", "blue", "BuySellDiff_eq"),
            ("bsd%_fu", "orange", "BuySellDiff_fu"),
            ("tot%_eq", "blue", "TotBuySell_eq"),
            ("tot%_fu", "orange", "TotBuySell_fu"),
        ]

        # Sidebar selector for which column to plot
        col_options = [c[0] for c in chart_specs]
        selected_col = st.selectbox("Select metric to plot:", col_options)

        # Get color and title for the selected column
        spec_map = {c[0]: (c[1], c[2]) for c in chart_specs}
        color, title = spec_map[selected_col]

        # Loop through all stocks
        for stock in fno_stocks:
            st.markdown(f"### {stock}")
            df_all = buysell_fno_func(stock)
            if not df_all.empty and selected_col in df_all.columns:
                df_all['Time'] = pd.to_datetime(df_all['Time'], format="%H:%M", errors="coerce")
                if selected_col == "Volchg_eq":
                    df_all['Volchg_eq'] = round(df_all['Volchg_eq'] / 1000, 2)
                plot_df = df_all.reset_index(drop=True)

                chart = (
                    alt.Chart(plot_df)
                    .mark_line(point=True)
                    .encode(x="Time:T", y=f"{selected_col}:Q", color=alt.value(color))
                    .properties(width=1000, height=200, title=f"{title} for {stock}")
                )
                st.altair_chart(chart, use_container_width=True)
            else:
                st.warning(f"No data found for {stock}")
# Out:
# 2026-02-25 15:15:32.870 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.873 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-02-25 15:15:32.880 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.910
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/shail/.local/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-02-25 15:15:32.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.932 Session state does not function when running a script without `streamlit run`
# 2026-02-25 15:15:32.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.950 No runtime found, using MemoryCacheStorageManager
# 2026-02-25 15:15:32.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:32.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.029 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-25 15:15:33.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.047 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-25 15:15:33.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.064 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-25 15:15:33.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.082 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-25 15:15:33.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.099 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-25 15:15:33.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.116 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-25 15:15:33.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.134 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-25 15:15:33.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.153 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-25 15:15:33.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.172 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-25 15:15:33.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 15:15:33.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
db_path = os.path.join(BASE_DIR_db, "niftybank.db")

# %%
stock = 'SBIN'

# %%
    todays_date = date.today()
    with sqlite3.connect(db_path) as tg_conn:
        tg_query = f"""
            SELECT * FROM niftybank
            WHERE Date = "{todays_date}" AND Stock = "{stock}"
            ORDER BY Time DESC
        """
        tgdf = pd.read_sql_query(tg_query, tg_conn)

# %%
tgdf.head()
# Out:
#   Stock        Date   Time fetch_time  Tbuy_eq  Tsell_eq     Tvalue_eq  \
# 0  SBIN  2026-02-25  15:10      15:09   594144    697959  2.008629e+10
# 1  SBIN  2026-02-25  15:09      15:07   594336    709924  2.001161e+10
# 2  SBIN  2026-02-25  15:08      15:07   597347    712136  1.989211e+10
# 3  SBIN  2026-02-25  15:07      15:05   587507    718903  1.978256e+10
# 4  SBIN  2026-02-25  15:06      15:05   620065    730024  1.962743e+10
#
#     Tvol_eq  High_eq  PrChg_eq  ...  Ltp_eq  Vwap_eq  Ltp_fu PrChg_fu  \
# 0  16646464   1228.1     -22.7  ...  1223.3  1206.64  1207.9    -23.1
# 1  16584299   1228.1     -22.8  ...  1223.3  1206.66    1208      -23
# 2  16484715   1228.1     -22.8  ...  1223.3  1206.70    1208      -23
# 3  16393392   1228.1     -22.8  ...  1223.3  1206.74  1208.2    -22.8
# 4  16264300   1228.1     -21.6  ...  1223.3  1206.78  1208.2    -22.8
#
#   %Prchg_fu  Tsell_fu Tbuy_fu Tvol_fu      Tvalue_fu   fuOI
# 0     -1.88   1037250  764250   22245    20277096075  68953
# 1     -1.87   1014750  774750   22039  20090476912.5  68907
# 2     -1.87   1014750  774750   22039  20090476912.5  68907
# 3     -1.85   1017000  745500   21807  19880297032.5  68907
# 4     -1.85   1017000  745500   21807  19880297032.5  68907
#
# [5 rows x 21 columns]

# %%
# Load available stocks from niftybank table
with sqlite3.connect(os.path.join(BASE_DIR_db, "niftybank.db")) as conn:
    fno_df = pd.read_sql_query("SELECT * FROM niftybank ORDER BY Date DESC", conn)

# %%
fno_df.head()
# Out:
#        Stock        Date   Time fetch_time  Tbuy_eq  Tsell_eq     Tvalue_eq  \
# 0   HDFCBANK  2026-02-25  14:07      14:07   578745   1173735  1.603971e+10
# 1  ICICIBANK  2026-02-25  14:07      14:07   290886    486083  1.623474e+10
# 2       SBIN  2026-02-25  14:07      14:07   570196    771097  1.450257e+10
# 3  KOTAKBANK  2026-02-25  14:07      14:07   750031    937094  2.719067e+09
# 4   AXISBANK  2026-02-25  14:07      14:07   247641    370721  4.427480e+09
#
#     Tvol_eq  High_eq  PrChg_eq  ...  Ltp_eq  Vwap_eq  Ltp_fu PrChg_fu  \
# 0  17616571   916.00     -5.40  ...   910.5   910.49   911.3    -6.05
# 1  11605033  1404.00     15.80  ...  1384.8  1398.94    1405     10.3
# 2  11994911  1228.10    -23.90  ...  1223.3  1209.06  1206.1    -24.9
# 3   6396150   430.15     -4.35  ...   427.7   425.11  424.55     -4.9
# 4   3172456  1400.80     10.70  ...  1387.6  1395.60  1400.9      7.9
#
#   %Prchg_fu  Tsell_fu Tbuy_fu Tvol_fu      Tvalue_fu    fuOI
# 0     -0.66   1543300  388300   19218     9700525725  496465
# 1      0.74    698600  426300    9388     9242429672  145755
# 2     -2.02    993000  723750   18063  16488493447.5   68603
# 3     -1.14   1450000  786000    3970     3393238400   95623
# 4      0.57    303125  328750    4762     4168000025   97533
#
# [5 rows x 21 columns]

# %%
fno_df['Stock'].unique()
# Out:
# array(['HDFCBANK', 'ICICIBANK', 'SBIN', 'KOTAKBANK', 'AXISBANK',
#        'FEDERALBNK', 'CANBK', 'BANKBARODA', 'UNIONBANK', 'PNB',
#        'IDFCFIRSTB', 'AUBANK', 'INDUSINDBK', 'YESBANK'], dtype=object)

# %%
buysell_df_single.head()
# Out:
#       Stock        Date   Time  %Prchg_eq  bsd%_eq  %Prchg_fu  bsd%_fu  \
# 0  HDFCBANK  2026-02-25  15:15      -0.34   -96.87      -0.31  -213.23
# 1  HDFCBANK  2026-02-25  15:14      -0.34   -91.23      -0.31  -213.23
# 2  HDFCBANK  2026-02-25  15:13      -0.34   -91.23      -0.42  -224.02
# 3  HDFCBANK  2026-02-25  15:12      -0.40  -119.65      -0.42  -224.02
# 4  HDFCBANK  2026-02-25  15:11      -0.40  -119.65      -0.38  -216.22
#
#    tot%_eq  tot%_fu  Tbuy_eq  ...  var%_eq  ValChg%_fu  Valchg_fu  VolChg%_fu  \
# 0   -32.63   -51.60   572778  ...    -0.01        0.00      0.000        0.00
# 1   -31.33   -51.60   578807  ...     0.00        0.78      9.652        0.78
# 2   -31.33   -52.83   578807  ...     0.00        0.00      0.000        0.00
# 3   -37.43   -52.83   527624  ...     0.00        0.56      6.930        0.56
# 4   -37.43   -51.95   527624  ...    -0.01        0.00      0.000        0.00
#
#    Volchg_fu  var%_fu  avg_eq  oichg_fu     avg_fu   avgOI_fu
# 0        0.0      0.0     0.0       0.0        NaN        NaN
# 1      192.0      0.0     NaN       0.0  502712.60        inf
# 2        0.0      0.0     0.0       0.0        NaN        NaN
# 3      138.0      0.0     NaN      22.0  502182.12  3150051.5
# 4        0.0      0.0     0.0       0.0        NaN        NaN
#
# [5 rows x 38 columns]

# %%
buysell_df_single.columns
# Out:
# Index(['Stock', 'Date', 'Time', '%Prchg_eq', 'bsd%_eq', '%Prchg_fu', 'bsd%_fu',
#        'tot%_eq', 'tot%_fu', 'Tbuy_eq', 'Tsell_eq', 'Tvalue_eq', 'Tvol_eq',
#        'High_eq', 'PrChg_eq', 'Ltp_eq', 'Vwap_eq', 'Ltp_fu', 'PrChg_fu',
#        'Tsell_fu', 'Tbuy_fu', 'Tvol_fu', 'Tvalue_fu', 'fuOI', 'ValChg%_eq',
#        'Valchg_eq', 'VolChg%_eq', 'Volchg_eq', 'var%_eq', 'ValChg%_fu',
#        'Valchg_fu', 'VolChg%_fu', 'Volchg_fu', 'var%_fu', 'avg_eq', 'oichg_fu',
#        'avg_fu', 'avgOI_fu'],
#       dtype='object')

# %%
    newcol = ['Stock', 'Date', 'Time', '%Prchg_eq','bsd%_eq', '%Prchg_fu', 'bsd%_fu',
              'tot%_eq', 'tot%_fu', 'Tbuy_eq', 'Tsell_eq', 
              'High_eq', 'PrChg_eq', 'Ltp_eq', 'Vwap_eq', 'Ltp_fu','PrChg_fu',
              'Tsell_fu', 'Tbuy_fu','fuOI',
              'ValChg%_eq', 'Valchg_eq', 'VolChg%_eq', 'Volchg_eq', 'var%_eq',
              'ValChg%_fu', 'Valchg_fu', 'VolChg%_fu', 'Volchg_fu', 'VolChg%_fu','var%_fu',
              'avg_eq', 'oichg_fu']

# %%
buysell_df_single.head()
# Out:
#       Stock        Date   Time  %Prchg_eq  bsd%_eq  %Prchg_fu  bsd%_fu  \
# 0  HDFCBANK  2026-02-25  15:15      -0.34   -96.87      -0.31  -213.23
# 1  HDFCBANK  2026-02-25  15:14      -0.34   -91.23      -0.31  -213.23
# 2  HDFCBANK  2026-02-25  15:13      -0.34   -91.23      -0.42  -224.02
# 3  HDFCBANK  2026-02-25  15:12      -0.40  -119.65      -0.42  -224.02
# 4  HDFCBANK  2026-02-25  15:11      -0.40  -119.65      -0.38  -216.22
#
#    tot%_eq  tot%_fu  Tbuy_eq  ...  var%_eq  ValChg%_fu  Valchg_fu  VolChg%_fu  \
# 0   -32.63   -51.60   572778  ...    -0.01        0.00      0.000        0.00
# 1   -31.33   -51.60   578807  ...     0.00        0.78      9.652        0.78
# 2   -31.33   -52.83   578807  ...     0.00        0.00      0.000        0.00
# 3   -37.43   -52.83   527624  ...     0.00        0.56      6.930        0.56
# 4   -37.43   -51.95   527624  ...    -0.01        0.00      0.000        0.00
#
#    Volchg_fu  var%_fu  avg_eq  oichg_fu     avg_fu   avgOI_fu
# 0        0.0      0.0     0.0       0.0        NaN        NaN
# 1      192.0      0.0     NaN       0.0  502712.60        inf
# 2        0.0      0.0     0.0       0.0        NaN        NaN
# 3      138.0      0.0     NaN      22.0  502182.12  3150051.5
# 4        0.0      0.0     0.0       0.0        NaN        NaN
#
# [5 rows x 38 columns]

# %%
newdf = buysell_df_single[newcol]
newdf.head(21)
# Out:
#        Stock        Date   Time  %Prchg_eq  bsd%_eq  %Prchg_fu  bsd%_fu  \
# 0   HDFCBANK  2026-02-25  15:15      -0.34   -96.87      -0.31  -213.23
# 1   HDFCBANK  2026-02-25  15:14      -0.34   -91.23      -0.31  -213.23
# 2   HDFCBANK  2026-02-25  15:13      -0.34   -91.23      -0.42  -224.02
# 3   HDFCBANK  2026-02-25  15:12      -0.40  -119.65      -0.42  -224.02
# 4   HDFCBANK  2026-02-25  15:11      -0.40  -119.65      -0.38  -216.22
# 5   HDFCBANK  2026-02-25  15:10      -0.33   -96.12      -0.38  -216.22
# 6   HDFCBANK  2026-02-25  15:09      -0.31   -81.36      -0.32  -211.82
# 7   HDFCBANK  2026-02-25  15:08      -0.36  -102.52      -0.32  -211.82
# 8   HDFCBANK  2026-02-25  15:07      -0.33  -103.28      -0.32  -202.81
# 9   HDFCBANK  2026-02-25  15:06      -0.24   -76.54      -0.32  -202.81
# 10  HDFCBANK  2026-02-25  15:05      -0.29   -88.65      -0.29  -222.45
# 11  HDFCBANK  2026-02-25  15:04      -0.26   -86.33      -0.29  -222.45
# 12  HDFCBANK  2026-02-25  15:03      -0.25   -74.21      -0.32  -224.97
# 13  HDFCBANK  2026-02-25  15:02      -0.28   -82.08      -0.32  -224.97
# 14  HDFCBANK  2026-02-25  15:01      -0.28   -82.03      -0.27  -226.94
# 15  HDFCBANK  2026-02-25  15:00      -0.28   -77.00      -0.27  -226.94
# 16  HDFCBANK  2026-02-25  14:59      -0.37   -94.09      -0.35  -248.16
# 17  HDFCBANK  2026-02-25  14:58      -0.27   -82.49      -0.35  -248.16
# 18  HDFCBANK  2026-02-25  14:57      -0.33   -86.87      -0.34  -237.60
# 19  HDFCBANK  2026-02-25  14:56      -0.32   -80.99      -0.34  -237.60
# 20  HDFCBANK  2026-02-25  14:55      -0.38   -78.46      -0.39  -230.55
#
#     tot%_eq  tot%_fu  Tbuy_eq  ...  Volchg_eq  var%_eq  ValChg%_fu  Valchg_fu  \
# 0    -32.63   -51.60   572778  ...   236741.0    -0.01        0.00      0.000
# 1    -31.33   -51.60   578807  ...        0.0     0.00        0.78      9.652
# 2    -31.33   -52.83   578807  ...   427826.0     0.00        0.00      0.000
# 3    -37.43   -52.83   527624  ...        0.0     0.00        0.56      6.930
# 4    -37.43   -51.95   527624  ...   351329.0    -0.01        0.00      0.000
# 5    -32.46   -51.95   579668  ...   165302.0     0.00        0.49      6.036
# 6    -28.92   -51.44   620728  ...   285750.0     0.00        0.00      0.000
# 7    -33.89   -51.44   591945  ...   131359.0     0.00        0.84     10.208
# 8    -34.05   -50.35   577117  ...   258518.0     0.00        0.00      0.000
# 9    -27.68   -50.35   626186  ...   168748.0     0.00        0.87     10.473
# 10   -30.71   -52.66   595018  ...   137298.0     0.00        0.00      0.000
# 11   -30.15   -52.66   616685  ...    83635.0     0.00        0.45      5.381
# 12   -27.06   -52.94   633774  ...    44020.0     0.00        0.00      0.000
# 13   -29.10   -52.94   594922  ...   338864.0     0.00        0.80      9.503
# 14   -29.09   -53.16   603219  ...     5915.0     0.00        0.00      0.000
# 15   -27.80   -53.16   630425  ...    87858.0     0.00        0.61      7.247
# 16   -31.99   -55.37   584835  ...    86559.0     0.00        0.00      0.000
# 17   -29.20   -55.37   599267  ...    77934.0     0.00        0.65      7.638
# 18   -30.28   -54.30   600302  ...    34002.0     0.00        0.00      0.000
# 19   -28.82   -54.30   612632  ...    33367.0     0.00        0.76      8.912
# 20   -28.18   -53.55   630006  ...    44565.0     0.00        0.00      0.000
#
#     VolChg%_fu  Volchg_fu  VolChg%_fu  var%_fu  avg_eq  oichg_fu
# 0         0.00        0.0        0.00      0.0     0.0       0.0
# 1         0.78      192.0        0.78      0.0     NaN       0.0
# 2         0.00        0.0        0.00      0.0     0.0       0.0
# 3         0.56      138.0        0.56      0.0     NaN      22.0
# 4         0.00        0.0        0.00      0.0     0.0       0.0
# 5         0.49      120.0        0.49      0.0     0.0     130.0
# 6         0.00        0.0        0.00      0.0     0.0       0.0
# 7         0.84      203.0        0.84      0.0     0.0       0.0
# 8         0.00        0.0        0.00      0.0     0.0       0.0
# 9         0.87      208.0        0.87      0.0     0.0     129.0
# 10        0.00        0.0        0.00      0.0     0.0       0.0
# 11        0.45      107.0        0.45      0.0     0.0     -38.0
# 12        0.00        0.0        0.00      0.0     0.0       0.0
# 13        0.80      189.0        0.80      0.0     0.0      68.0
# 14        0.00        0.0        0.00      0.0     0.0       0.0
# 15        0.61      144.0        0.61      0.0     0.0       0.0
# 16        0.00        0.0        0.00      0.0     0.0       0.0
# 17        0.65      152.0        0.65      0.0     0.0      29.0
# 18        0.00        0.0        0.00      0.0     0.0       0.0
# 19        0.76      177.0        0.76      0.0     0.0      47.0
# 20        0.00        0.0        0.00      0.0     0.0       0.0
#
# [21 rows x 33 columns]

# %%
import os
import sqlite3
import pandas as pd
import streamlit as st
import altair as alt
import numpy as np
import time
import requests
from datetime import date
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

BASE_DIR_db = "/home/shail/db"
BASE_DIR = "/home/shail/stockshortlisting"

# --- Page config ---
st.set_page_config(layout="wide")

@st.cache_data
def buysell_fno_func(stock: str):
    """
    Process buy/sell FNO data for a single stock from niftybank.db/niftybank table.
    """
    db_path = os.path.join(BASE_DIR_db, "niftybank.db")
    todays_date = date.today()
    with sqlite3.connect(db_path) as tg_conn:
        tg_query = f"""
            SELECT * FROM niftybank
            WHERE Date = "{todays_date}" AND Stock = "{stock}"
            ORDER BY Time DESC
        """
        tgdf = pd.read_sql_query(tg_query, tg_conn)

    alldf = tgdf[tgdf['Stock'] == stock].sort_values(by=['Time'], ascending=False).reset_index(drop=True)
    if alldf.empty:
        return pd.DataFrame()

    numeric_cols = [
        'Tbuy_eq', 'Tsell_eq', 'Tvalue_eq', 'Tvol_eq',
        'High_eq', 'PrChg_eq', '%Prchg_eq', 'Ltp_eq', 'Vwap_eq', 'Ltp_fu',
        'PrChg_fu', '%Prchg_fu', 'Tsell_fu', 'Tbuy_fu', 'Tvol_fu',
        'Tvalue_fu', 'fuOI'
    ]
    alldf[numeric_cols] = alldf[numeric_cols].apply(pd.to_numeric, errors='coerce')
    alldf.fillna(0, inplace=True)

    # Transformations
    alldf['Tvalue_eq'] = alldf['Tvalue_eq'] / 10000000
    alldf['ValChg%_eq'] = round((alldf['Tvalue_eq'] - alldf['Tvalue_eq'].shift(-1)) * 100 / alldf['Tvalue_eq'].shift(-1), 2)
    alldf['Valchg_eq'] = alldf['Tvalue_eq'] - alldf['Tvalue_eq'].shift(-1)
    alldf['VolChg%_eq'] = round((alldf['Tvol_eq'] - alldf['Tvol_eq'].shift(-1)) * 100 / alldf['Tvol_eq'].shift(-1), 2)
    alldf['Volchg_eq'] = round((alldf['Tvol_eq'] - alldf['Tvol_eq'].shift(-1)), 2)
    alldf['var%_eq'] = alldf['ValChg%_eq'] - alldf['VolChg%_eq']
    alldf['bsd%_eq'] = round(((alldf['Tbuy_eq'] - alldf['Tsell_eq']) * 100) / alldf['Tbuy_eq'], 2)

    alldf['ValChg%_fu'] = round((alldf['Tvalue_fu'] - alldf['Tvalue_fu'].shift(-1)) * 100 / alldf['Tvalue_fu'].shift(-1), 2)
    alldf['Valchg_fu'] = round((alldf['Tvalue_fu'] - alldf['Tvalue_fu'].shift(-1)), 3)
    alldf['VolChg%_fu'] = round((alldf['Tvol_fu'] - alldf['Tvol_fu'].shift(-1)) * 100 / alldf['Tvol_fu'].shift(-1), 2)
    alldf['Volchg_fu'] = round((alldf['Tvol_fu'] - alldf['Tvol_fu'].shift(-1)), 2)
    alldf['var%_fu'] = alldf['ValChg%_fu'] - alldf['VolChg%_fu']
    alldf['bsd%_fu'] = round(((alldf['Tbuy_fu'] - alldf['Tsell_fu']) * 100) / alldf['Tbuy_fu'], 2)

    alldf['tot%_eq'] = round(((alldf['Tbuy_eq'] - alldf['Tsell_eq']) * 100) / (alldf['Tbuy_eq'] + alldf['Tsell_eq']), 2)
    alldf['tot%_fu'] = round(((alldf['Tbuy_fu'] - alldf['Tsell_fu']) * 100) / (alldf['Tbuy_fu'] + alldf['Tsell_fu']), 2)
    alldf['avg_eq'] = round(alldf['Valchg_eq'] / (alldf['Volchg_eq']), 2)
    alldf['oichg_fu'] = round(alldf['fuOI'] - (alldf['fuOI'].shift(-1)), 2)
    alldf['avg_fu'] = round(alldf['Valchg_fu'] / (alldf['Volchg_fu']), 2)
    alldf['avgOI_fu'] = round(alldf['Valchg_fu'] / (alldf['oichg_fu']), 2)
    alldf['Valchg_fu'] = round(alldf['Valchg_fu'] / 10000000, 3)

    newcol = ['Stock', 'Date', 'Time', '%Prchg_eq','bsd%_eq', '%Prchg_fu', 'bsd%_fu',
              'tot%_eq', 'tot%_fu', 'Tbuy_eq', 'Tsell_eq', 
              'High_eq', 'PrChg_eq', 'Ltp_eq', 'Vwap_eq', 'Ltp_fu','PrChg_fu',
              'Tsell_fu', 'Tbuy_fu','fuOI',
              'ValChg%_eq', 'Valchg_eq', 'VolChg%_eq', 'Volchg_eq', 'var%_eq',
              'ValChg%_fu', 'Valchg_fu', 'VolChg%_fu', 'Volchg_fu','var%_fu',
              'avg_eq', 'oichg_fu']
    alldf = alldf[newcol]
    return alldf

@st.cache_data
def shortlist_func(stock: str):
    """
    Process bhavcopy + 52-week data for a single stock.
    """
    db_path = os.path.join(BASE_DIR_db, "fullbhavcopy.db")
    conn = sqlite3.connect(db_path)

    # Load 52-week high/low data
    hl_52w_path = os.path.join(BASE_DIR, "52weekhl", "52_wk_High_low.csv")
    df1 = pd.read_csv(hl_52w_path)

    # Define all column renames in one dictionary
    rename_map = {
        'Adjusted_52_Week_High': '52WH',
        'Adjusted_52_Week_Low': '52WL',
        'TURNOVER_LACS': 'Val_CR',
        'TTL_TRD_QNTY': 'Vol',
        'HIGH_PRICE': 'HiPr',
        'LAST_PRICE': 'LTP',
        'AVG_PRICE': 'AvgPr',
        'SYMBOL': 'Stock',
        'DATE': 'Date',
        'LOW_PRICE': 'LoPr',
        'PREV_CLOSE': 'PvPr',
        'CLOSE_PRICE': 'ClPr'
    }

    df1.rename(columns=rename_map, inplace=True)

    query = f"SELECT * FROM nsestock_t WHERE SYMBOL = '{stock}' ORDER BY Date DESC LIMIT 360"
    hl_df = pd.read_sql_query(query, conn)

    hl_df['DELIV_QTY'] = hl_df['DELIV_QTY'].astype(float)
    hl_df.rename(columns=rename_map, inplace=True)

    hl_df['Val_CR'] = round(hl_df['Val_CR'] / 100, 3)
    hl_df = pd.merge(hl_df, df1[['Stock', '52WH', '52WL']], on='Stock', how='left')

    # Derived metrics
    hl_df['DlyAvg_10'] = round(hl_df['DELIV_QTY'].rolling(window=10, min_periods=10).mean().shift(-10), 1)
    hl_df['DlyRto_10'] = round(hl_df['DELIV_QTY'] / hl_df['DlyAvg_10'], 1)
    hl_df['Pr_chg'] = round(hl_df['ClPr'] - hl_df['PvPr'], 2)
    hl_df['Pr_chg_%'] = round((hl_df['ClPr'] - hl_df['PvPr']) * 100 / hl_df['PvPr'], 2)
    hl_df['LO52WNr%'] = round((hl_df['ClPr'] - hl_df['52WL']) * 100 / hl_df['52WL'], 2)
    hl_df['HI52WNr%'] = round((hl_df['52WH'] - hl_df['ClPr']) * 100 / hl_df['52WH'], 2)
    hl_df['DayHiNr%'] = round((hl_df['HiPr'] - hl_df['ClPr']) * 100 / hl_df['HiPr'], 2)
    hl_df['DayLoNr%'] = round((hl_df['ClPr'] - hl_df['LoPr']) * 100 / hl_df['LoPr'], 2)

    # Rolling averages
    periods = [1, 5, 10, 21, 50, 66, 96, 125, 190, 252]
    for period in periods:
        hl_df[f'SMA_{period}'] = round(hl_df['ClPr'].rolling(window=period, min_periods=period).mean().shift(-period), 1)
        hl_df[f'VolAvg_{period}'] = round(hl_df['Vol'].rolling(window=period, min_periods=period).mean().shift(-period), 1)
        hl_df[f'ValAvg_{period}'] = round(hl_df['Val_CR'].rolling(window=period, min_periods=period).mean().shift(-period), 1)
        hl_df.loc[:, f'ValChg%_Avg_{period}'] = round((hl_df['Val_CR'] - hl_df[f'ValAvg_{period}']) * 100 / hl_df[f'ValAvg_{period}'], 2)
        hl_df.loc[:, f'VolChg%_Avg_{period}'] = round((hl_df['Vol'] - hl_df[f'VolAvg_{period}']) * 100 / hl_df[f'VolAvg_{period}'], 2)

    hl_df['VolRto_10'] = round(hl_df['Vol'] / hl_df['VolAvg_10'], 1)
    hl_df.fillna(0, inplace=True)

    hl_df['Vol_lac'] = round(hl_df['Vol'] / 100000, 3)
    specific_map = { 'Pr_chg_%': 'prchg%', 'DlyRto_10': 'dly_RTO', 'VolRto_10': 'qty_rto' }
    
    # Reorder columns
     # --- Pattern-based rename: remove "Avg_" everywhere --- 
    hl_df.rename(columns=lambda c: c.replace("Avg_", ""), inplace=True)
    hl_df.rename(columns=specific_map, inplace=True)
    newcol = [
    'Stock', 'Date', 'dly_RTO', 'prchg%', 'qty_rto','LTP', 'HiPr', 
    'ValChg%_10', 'VolChg%_10', 'ValChg%_21', 'VolChg%_21',
    'ValChg%_50', 'VolChg%_50',
    'AvgPr', 'Val_CR','Vol_lac', 'LoPr', 'ClPr',
    'NO_OF_TRADES', 'DELIV_QTY', 'DELIV_PER',
    '52WH', '52WL', 'Dly10', 'Pr_chg', 'LO52WNr%', 'HI52WNr%',
    'DayHiNr%', 'DayLoNr%',
    'SMA_1', 'Vol1', 'Val1', 'ValChg%_1', 'VolChg%_1',
    'SMA_5', 'Vol5', 'Val5', 'ValChg%_5', 'VolChg%_5',
    'SMA_10', 'Vol10', 'Val10',
    'SMA_21', 'Vol21', 'Val21',
    'SMA_50', 'Vol50', 'Val50',
    'SMA_66', 'Vol66', 'Val66', 'ValChg%_66', 'VolChg%_66',
    'SMA_96', 'Vol96', 'Val96', 'ValChg%_96', 'VolChg%_96',
    'SMA_125', 'Vol125', 'Val125', 'ValChg%_125', 'VolChg%_125',
    'SMA_190', 'Vol190', 'Val190', 'ValChg%_190', 'VolChg%_190',
    'SMA_252', 'Vol252', 'Val252', 'ValChg%_252', 'VolChg%_252',
    'Vol'
    ]

    hl_df = hl_df[newcol]
 
    conn.close()
    return hl_df
def fetch_nse_data(stock: str):
    """
    Fetch NSE JSON data (quote + change history) for a single stock.
    Returns (qtyjson, chgjson) or (None, None) if request fails.
    """
    headers = {
        'User-Agent': 'Mozilla/5.0',
        'Referer': f'https://www.nseindia.com/get-quotes/equity?symbol={stock}',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
        'Accept-Language': 'en-US,en;q=0.5'
    }

    encoded_stock = stock.replace("&", "%26")
    main_url = "https://www.nseindia.com"
    qty_url = (
        f"https://www.nseindia.com/api/NextApi/apiClient/GetQuoteApi?"
        f"functionName=getSymbolData&marketType=N&series=EQ&symbol={encoded_stock}"
    )
    chg_url = (
        f"https://www.nseindia.com/api/NextApi/apiClient/GetQuoteApi?"
        f"functionName=getYearwiseData&symbol={encoded_stock}EQN"
    )

    session = requests.Session()
    retry = Retry(
        total=2,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=["GET"]
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount("https://", adapter)
    session.mount("http://", adapter)

    try:
        # Warm up session
        session.get(main_url, headers=headers)
        time.sleep(1)  # polite delay
        qty_resp = session.get(qty_url, headers=headers)
        qty_resp.raise_for_status()
        chg_resp = session.get(chg_url, headers=headers)
        chg_resp.raise_for_status()
        return qty_resp.json(), chg_resp.json()
    except requests.exceptions.RequestException as e:
        st.error(f"Error fetching NSE data for {stock}: {e}")
        return None, None

def parse_time(df, fmt):
    if 'Time' in df.columns and 'Date' in df.columns:
        df['DateTime'] = pd.to_datetime(
            df['Date'].astype(str) + ' ' + df['Time'].astype(str),
            format=f"%Y-%m-%d {fmt}", errors="coerce"
        )
        #df.sort_values(by='DateTime', inplace=True)
        df.sort_values(by='DateTime', ascending=False, inplace=True)
        df.reset_index(drop=True, inplace=True)
    return df


    
# --- Sidebar selectors ---
st.sidebar.header("Filter Options")

with sqlite3.connect(os.path.join(BASE_DIR_db, "niftybank.db")) as conn:
    fno_df = pd.read_sql_query("SELECT DISTINCT Stock FROM niftybank ORDER BY Stock", conn)

fno_stocks = fno_df['Stock'].unique() if not fno_df.empty else []

# Single select box (no manual input)
selected_stock = st.sidebar.selectbox(
    "Select a Bank Nifty Stock:",
    fno_stocks
)

tab1, tab2, tab3 = st.tabs(["FNO DlyRatio", "Fu & Eq BuySellData", "All Stocks Graphs"])

if selected_stock:
    stock_to_analyze = selected_stock
    buysell_df_single = buysell_fno_func(stock_to_analyze)
    shortlisted_df_single = shortlist_func(stock_to_analyze)
    qtyjson, chgjson = fetch_nse_data(stock_to_analyze)


    # --- Tab 1 ---
    with tab1:
        st.subheader(f"Fu & Eq BuySell Order Graphs for {stock_to_analyze}")
        if not buysell_df_single.empty:
            filtered_df = buysell_df_single.copy()
            #filtered_df['Time'] = pd.to_datetime(filtered_df['Time'], format="%H:%M", errors="coerce")
            filtered_df['Time'] = filtered_df['Time'].astype(str)  # keep as "HH:MM"
            filtered_df['Volchg_eq'] = round(filtered_df['Volchg_eq'] / 1000, 2)
            plot_df = filtered_df.reset_index(drop=True)

            chart_specs = [
                ("%Prchg_eq", "blue", "%Prchg_eq"),
                #("Ltp_eq", "blue", "ltp"),
                ("Valchg_eq", "blue", "Valchg_eq(cr)"),
                ("Volchg_eq", "green", "Volchg_eq(K)"),
                ("PrChg_eq", "orange", "PriceChg_eq"),
                ("%Prchg_fu", "orange", "%Prchg_fu"),
                ("Valchg_fu", "blue", "Valchg_fu(cr)"),
                ("Volchg_fu", "green", "Volchg_fu(K)"),
                ("bsd%_eq", "blue", "BuySellDiff_eq"),
                ("bsd%_fu", "orange", "BuySellDiff_fu"),
                ("tot%_eq", "blue", "TotBuySell_eq"),
                ("tot%_fu", "orange", "TotBuySell_fu"),
            ]
            for col, color, title in chart_specs:
                if col in plot_df.columns:
                    chart = (
                        alt.Chart(plot_df)
                        .mark_line(point=True)
                        #.encode(x="Time:T", y=f"{col}:Q", color=alt.value(color))
                        .encode(
                                x=alt.X("Time:N", title="Time"),   # treat as nominal
                                y=f"{col}:Q",
                                color=alt.value(color)
                                )
                        .properties(width=1000, height=200, title=f"{title} for {stock_to_analyze}")
                    )
                    st.altair_chart(chart, use_container_width=True)
        else:
            st.warning(f"No BuySell data found for {stock_to_analyze}")

        # Fetch NSE API JSON for the selected FNO stock
        st.subheader(f"Current Price Info for {stock_to_analyze}")   
        qtyjson, chgjson = fetch_nse_data(stock_to_analyze)    

        # Derived metrics
        DayLoNrP, DayHiNrP = None, None
        if qtyjson:
            meta = qtyjson['equityResponse'][0]['metaData']
            ltp = qtyjson['equityResponse'][0]['tradeInfo']['lastPrice']
            day_low = meta['dayLow']
            day_high = meta['dayHigh']
            DayLoNrP = np.round((ltp - day_low) * 100 / ltp, 2)
            DayHiNrP = np.round((day_high - ltp) * 100 / ltp, 2)    

        # Display metrics in rows of 5
        if qtyjson and chgjson:
            metrics = [
                ("Change%", qtyjson['equityResponse'][0]['metaData']['pChange']),
                ("DayHiNr%", DayHiNrP),
                ("DayHigh", qtyjson['equityResponse'][0]['metaData']['dayHigh']),
                ("WeekChg%", chgjson[0]['one_week_chng_per']),
                ("MonthChg%", chgjson[0]['one_month_chng_per']),
                ("Ltp", qtyjson['equityResponse'][0]['tradeInfo']['lastPrice']),
                ("DayLoNrP%", DayLoNrP),
                ("DayLow", qtyjson['equityResponse'][0]['metaData']['dayLow']),
                ("PrChg", qtyjson['equityResponse'][0]['metaData']['change']),
                ("3MonChg%", chgjson[0]['three_month_chng_per']),
            ]
            for i in range(0, len(metrics), 5):
                cols = st.columns([0.9] * 5)
                for j, (label, value) in enumerate(metrics[i:i+5]):
                    cols[j].metric(label, value, border=True)    

        st.subheader(f"Delivery Ratio History for {stock_to_analyze}")
        shortlisted_df_single

    # --- Tab 2 ---
    with tab2:
        st.subheader(f"Buy Sell Trade data for {stock_to_analyze}")
        st.dataframe(buysell_df_single)

# --- Tab 3 ---

    with tab3:
        st.subheader("All Bank Nifty Stocks")    

        # Define grouped chart specs: each entry is (columns, colors, title)
        chart_groups = [
            (["%Prchg_eq", "%Prchg_fu"], ["blue", "orange"], "% Price Change"),
            (["Valchg_eq", "Valchg_fu"], ["blue", "orange"], "Value Change (cr)"),
            (["Volchg_eq", "Volchg_fu"], ["green", "orange"], "Volume Change"),
            (["bsd%_eq", "bsd%_fu"], ["blue", "orange"], "Buy-Sell Diff"),
            (["tot%_eq", "tot%_fu"], ["blue", "orange"], "Total Buy-Sell %"),
            (["PrChg_eq", "PrChg_fu"], ["orange", "blue"], "Price Change"),
        ]    

        # Sidebar multiselect for groups
        group_options = [g[2] for g in chart_groups]
        selected_groups = st.multiselect(
            "Select metric groups to plot:",
            group_options,
            default=[group_options[0]]
        )    

        # Loop through all stocks (or change to [selected_stock] if you only want one)
        for stock in fno_stocks:
            st.markdown(f"##### {stock}")
            df_all = buysell_fno_func(stock)
            if not df_all.empty:
                # Combine Date + Time into full DateTime
                df_all['DateTime'] = pd.to_datetime(
                    df_all['Date'].astype(str) + " " + df_all['Time'].astype(str),
                    errors="coerce"
                )
                # Extract just the time string for tooltip
                df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")    

                if "Volchg_eq" in df_all.columns:
                    df_all['Volchg_eq'] = round(df_all['Volchg_eq'] / 1000, 2)    

                plot_df = df_all.reset_index(drop=True)    

                # Loop through each selected group
                for cols, colors, title in chart_groups:
                    if title in selected_groups:
                        layers = []
                        for col, color in zip(cols, colors):
                            if col in plot_df.columns:
                                layers.append(
                                    alt.Chart(plot_df)
                                    .mark_line(point=True)
                                    .encode(
                                        x=alt.X("DateTime:T", title="DateTime"),
                                        y=f"{col}:Q",
                                        color=alt.value(color),
                                        tooltip=["Stock", "Time", col]  # show stock, time, value
                                    )
                                )
                        if layers:
                            chart = alt.layer(*layers).properties(
                                width=800, height=250, title=f"{title} for {stock}"
                            )
                            st.altair_chart(chart, use_container_width=True)
            else:
                st.warning(f"No BuySell data found for {stock}")
###
# Out:
# 2026-02-26 10:34:11.727 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.729 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-02-26 10:34:11.733 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-02-26 10:34:11.738 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.912
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/shail/.local/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-02-26 10:34:11.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.923 Session state does not function when running a script without `streamlit run`
# 2026-02-26 10:34:11.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.928 No runtime found, using MemoryCacheStorageManager
# 2026-02-26 10:34:11.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:11.955 No runtime found, using MemoryCacheStorageManager
# 2026-02-26 10:34:11.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.548 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:13.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.582 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:13.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.604 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:13.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.631 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:13.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.646 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:13.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.661 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:13.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.676 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:13.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.702 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:13.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.718 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:13.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.735 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:13.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.751 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:13.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:13.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:15.265 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:15.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:15.424 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:15.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:15.554 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:15.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:15.788 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:15.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:15.981 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:15.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:15.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:16.107 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:16.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:16.253 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:16.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:16.372 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:16.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.380 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:16.511 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:16.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:16.615 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:16.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:16.704 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:16.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:16.838 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:16.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:16.931 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:16.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:16.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /tmp/ipykernel_271366/2462575721.py:373: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_all['TimeOnly'] = pd.to_datetime(df_all['Time'], errors="coerce").dt.strftime("%H:%M")
# 2026-02-26 10:34:17.031 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'` or specify an integer width.
# 2026-02-26 10:34:17.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:17.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 10:34:17.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
buysell_df_single
# Out:
#      Stock        Date   Time  %Prchg_eq  bsd%_eq  %Prchg_fu  bsd%_fu  \
# 0   AUBANK  2026-02-26  10:34      -0.17    16.32       0.07   -12.22
# 1   AUBANK  2026-02-26  10:33      -0.35    13.83      -0.05   -10.45
# 2   AUBANK  2026-02-26  10:32      -0.35    13.83      -0.05   -10.45
# 3   AUBANK  2026-02-26  10:31      -0.47     6.22      -0.23   -18.49
# 4   AUBANK  2026-02-26  10:30      -0.47     6.22      -0.23   -18.49
# ..     ...         ...    ...        ...      ...        ...      ...
# 84  AUBANK  2026-02-26  09:04       1.21  -168.43      -2.32  -206.90
# 85  AUBANK  2026-02-26  09:03       1.21  -181.91      -2.32  -206.90
# 86  AUBANK  2026-02-26  09:02       1.21  -181.91      -2.32  -206.90
# 87  AUBANK  2026-02-26  09:01      -0.21    25.49      -2.32  -206.90
# 88  AUBANK  2026-02-26  09:00      -0.21    25.49      -2.32  -206.90
#
#     tot%_eq  tot%_fu  Tbuy_eq  ...  VolChg%_eq  Volchg_eq  var%_eq  \
# 0      8.88    -5.76   189504  ...        2.02     7577.0     0.01
# 1      7.43    -4.96   183233  ...        0.00        0.0     0.00
# 2      7.43    -4.96   183233  ...        2.87    10468.0     0.01
# 3      3.21    -8.46   179353  ...        0.00        0.0     0.00
# 4      3.21    -8.46   179353  ...        1.89     6751.0     0.00
# ..      ...      ...      ...  ...         ...        ...      ...
# 84   -45.72   -50.85    10163  ...         NaN        0.0      NaN
# 85   -47.63   -50.85     7422  ...         NaN        0.0      NaN
# 86   -47.63   -50.85     7422  ...         NaN        0.0      NaN
# 87    14.61   -50.85      812  ...         NaN        0.0      NaN
# 88    14.61   -50.85      812  ...         NaN        NaN      NaN
#
#     ValChg%_fu  Valchg_fu  VolChg%_fu  Volchg_fu  var%_fu  avg_eq  oichg_fu
# 0         0.64      0.690        0.64        7.0     0.00     0.0       0.0
# 1         0.00      0.000        0.00        0.0     0.00     NaN       0.0
# 2         0.83      0.885        0.83        9.0     0.00     0.0       1.0
# 3         0.00      0.000        0.00        0.0     0.00     NaN       0.0
# 4         1.31      1.376        1.30       14.0     0.01     0.0       5.0
# ..         ...        ...         ...        ...      ...     ...       ...
# 84        0.00      0.000        0.00        0.0     0.00     NaN       0.0
# 85        0.00      0.000        0.00        0.0     0.00     NaN       0.0
# 86        0.00      0.000        0.00        0.0     0.00     NaN       0.0
# 87        0.00      0.000        0.00        0.0     0.00     NaN       0.0
# 88         NaN        NaN         NaN        NaN      NaN     NaN       NaN
#
# [89 rows x 32 columns]
